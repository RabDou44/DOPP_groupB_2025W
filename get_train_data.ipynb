# %%
import requests
import pathlib
import xml.etree.ElementTree as ET
import json
import time
import string
import sys
import pandas as pd
from deutsche_bahn_api import ApiAuthentication
import numpy as np
import re
from datetime import datetime, timedelta


BASE_URL = "https://apis.deutschebahn.com/db-api-marketplace/apis/timetables/v1/"
STATION_URL_1 = BASE_URL + "station/135899"

ALLOWED_UIC_PREFIXES = {
    "80": "Germany", "81": "Austria", "82": "Luxembourg", "84": "The Netherlands", 
    "87": "France", "88": "Belgium", "86": "Denmark", "74": "Sweden", 
    "10": "Finland", "83": "Italy", "71": "Spain", "94": "Portugal", 
    "79": "Slovenia", "78": "Croatia", "73": "Greece", "51": "Poland", 
    "54": "Czechia", "55": "Hungary", "56": "Slovakia", "53": "Romania", 
    "52": "Bulgaria", "25": "Estonia", "26": "Lithuania", "27": "Latvia",
    "70": "United Kingdom", "60": "Ireland"
}

DB_CLIENT_ID = "15e1384706df102d7c7502c78b266e3b"
DB_API_KEY = "2e71b6410f16f919b1ed934793e3a5bf"
DB_CLIENT_ID2 = "a9f83c55d26c3ee7f48f4ce887ec2a57"
DB_API_KEY2 = "422cac21a0a83876c75efb8806589ea0"

header2 = {
    "DB-Client-Id": DB_CLIENT_ID2,
    "DB-Api-Key": DB_API_KEY2,
    "accept": "application/xml"
}

def fetch_stations():
    url = f"{BASE_URL}/station/*"
    try:
        response = requests.get(url, headers=header2)
        response.encoding = 'utf-8' # Fix encoding for special chars
        if response.status_code == 200:
            return response.text
        elif response.status_code == 404:
            return None
        else:
            print(f"  [!] API Error {response.status_code} for '{char}'")
            return None
    except Exception as e:
        print(f"  [!] Request Exception: {e}")
        return None
    
def parse_and_filter(xml_data):
    """
    Parses XML and returns a list of dictionaries for valid EU stations.
    """
    valid_stations = []
    if not xml_data:
        return valid_stations

    try:
        root = ET.fromstring(xml_data)
        for station in root.findall("station"):
            name = station.get("name")
            eva = station.get("eva")
            ds100 = station.get("ds100")
            
            if not eva or not name:
                continue

            # 1. Country Filter (First 2 digits)
            uic_prefix = eva[:2]
            country_name = ALLOWED_UIC_PREFIXES.get(uic_prefix)

            if country_name:
                # 2. Island Name Filter
                # Check if any blocklist word appears in the station name

                valid_stations.append({
                    "EVA_ID": eva,
                    "Station_Name": name,
                    "DS100": ds100,
                    "Country": country_name,
                    "UIC_Code": uic_prefix
                })

    except ET.ParseError:
        print("  [!] XML Parsing Error")
    
    return valid_stations

# %%
#Verify API access
api_authentication = ApiAuthentication( DB_CLIENT_ID2, DB_API_KEY2)
success:bool = api_authentication.test_credentials()

# %% [markdown]
# # Fetching and Parsing DB Bahn stations

# %%
print("--- Starting EU Station Download ---")    
all_data = []
# Use a set to track EVAs we've already seen to prevent duplicates
seen_evas = set()
xml_content = fetch_stations()

if xml_content:
    batch = parse_and_filter(xml_content)
    
    new_count = 0
    for item in batch:
        if item['EVA_ID'] not in seen_evas:
            all_data.append(item)
            seen_evas.add(item['EVA_ID'])
            new_count += 1
    
    print(f"Found {len(batch)} items ({new_count} new).")
else:
    print("No data.")

    # Rate limit protection
    time.sleep(0.3)

print("-" * 30)
print("Processing Data with Pandas...")

# Create DataFrame
df = pd.DataFrame(all_data)

# Sort by Country then Name
if not df.empty:
    df = df.sort_values(by=["Country", "Station_Name"])
    
    # Display sample
    print(f"\nTotal Stations Found: {len(df)}")
    print("\nBreakdown by Country:")
    print(df['Country'].value_counts())
    
    # Save to CSV
    filename = "eu_stations_dataset.csv"
    df.to_csv(filename, index=False, encoding='utf-8-sig') # utf-8-sig for Excel compatibility
    print(f"\n[SUCCESS] Dataset saved to '{filename}'")
else:
    print("[!] No stations found. Check your API keys or Filter logic.")
# Out:
# --- Starting EU Station Download ---
# Found 28635 items (28635 new).
# ------------------------------
# Processing Data with Pandas...
#
# Total Stations Found: 28635
#
# Breakdown by Country:
# Country
# Germany           8426
# France            6351
# Poland            3811
# Czech Republic    3399
# Austria           3118
# Denmark            790
# Belgium            596
# Netherlands        445
# Italy              237
# Finland            215
# Spain              185
# Greece             179
# Luxembourg         147
# Slovakia           138
# Hungary            128
# United Kingdom      92
# Sweden              68
# Croatia             64
# Slovenia            62
# Ireland             47
# Latvia              29
# Lithuania           24
# Portugal            23
# Estonia             23
# Bulgaria            19
# Romania             19
# Name: count, dtype: int64
#
# [SUCCESS] Dataset saved to 'eu_stations_dataset.csv'

# %%
df.iloc[np.random.choice(df.shape[0],50)]
# Out:
#         EVA_ID                            Station_Name     DS100  \
# 17720  8175190  Oberland Abzw. Forsteralm, Gaflenz (A)     PAOOF
# 9550   5401020                                 Havrice     OTHVR
# 22196  8070974                      Schmiechen Albbahn      TSHA
# 4922   5100873                                 Cieszyn     OPCZY
# 23880   256762                               Starnberg   D256762
# 4710   8703094                               Chevaigne     OFCLK
# 17455  5499756                        Novina obratiste     PTNOE
# 18853  8101352                            Pfaffstätten     OAPFT
# 20953  8650611                   Ringsted St. (togbus)     PDRTB
# 3716   8085001                   Bruchsal Schloßgarten      RBRD
# 28118  5171002                            Zakroczym 03     PPZOM
# 24617  5100058                  Szklarska Poreba Gorna     XPSPG
# 18002  5402234                        Olesna na Morave     OTONM
# 93     8706786                 Achères Ville Noctilien     PFCFC
# 22671   102770          Seulberg Linde, Friedrichsdorf     FSG B
# 13626  5403744                            Lenora zast.     OTLRZ
# 17409  8701689                       Nouvion-sur-Meuse     OFNSM
# 20233  5402592                                  Pysely     OTPYY
# 2447   8089043                   Berlin Treptower Park       BTP
# 18241  8004692                              Ostelsheim      TOSH
# 1885   8000783                              Baiersdorf       NBD
# 1754    518516                    Bahnhof, Schriesheim        RS
# 6812   8013477                                  Erkner      BERK
# 26748  8071052                    Walddrehna Dorfplatz     BWA D
# 6035   8001519                 Dortmund-Nette/Oestrich      EDOO
# 3813   8071266                  Bräunlingen In Stetten  D8071266
# 14607  5401874                                  Lupene     OTLUP
# 8559   8100146                   Greifenburg-Weißensee      OAGW
# 24736  8089127                              Tantow(Gr)       WXT
# 19495  5480264                  Praha Arbesovo namesti     PTPAA
# 2881   8001828                          Bitburg-Erdorf       SED
# 12197  5101772                          Krakow Zlocien     PPKZN
# 6198   8200613                         Dudelange-Ville      XLDV
# 12796  8705893           La Roquette (Hotel la Rocade)     PFAWN
# 23573  8701958                    St-Florentin-Vergign     OFSFV
# 2443   8089115                          Berlin Südende      BSDE
# 26165  8704824                          Vesinet Centre     OFVIS
# 9865   8011867                        Herzberg(Elster)      LHZW
# 9819   5401033                             Herman obec     OTHEO
# 920    8080060                Augustusburg Bergstation      DAUG
# 18129  8601811                             Orehoved st      XDOH
# 24808  8706358                                Tauxigny     PFBON
# 22089  8100485                                Scheibbs     OASCB
# 28049  5104261                        Zabno k. Chojnic     OPZBC
# 8104   8701196                         Gestel(Lorient)     OFGLT
# 3967   8007226                             Burladingen      TBLD
# 5533   8079022                                Deezbüll      ADZB
# 18664  8706551                          Pau Les Halles     PFBVZ
# 24607  5170147            Szczytno, Dworzec Autobusowy     PPSAO
# 15275  8003897                      Marstetten-Aitrach      TMAR
#
#               Country UIC_Code
# 17720         Austria       81
# 9550   Czech Republic       54
# 22196         Germany       80
# 4922           Poland       51
# 23880         Estonia       25
# 4710           France       87
# 17455  Czech Republic       54
# 18853         Austria       81
# 20953         Denmark       86
# 3716          Germany       80
# 28118          Poland       51
# 24617          Poland       51
# 18002  Czech Republic       54
# 93             France       87
# 22671         Finland       10
# 13626  Czech Republic       54
# 17409          France       87
# 20233  Czech Republic       54
# 2447          Germany       80
# 18241         Germany       80
# 1885          Germany       80
# 1754           Poland       51
# 6812          Germany       80
# 26748         Germany       80
# 6035          Germany       80
# 3813          Germany       80
# 14607  Czech Republic       54
# 8559          Austria       81
# 24736         Germany       80
# 19495  Czech Republic       54
# 2881          Germany       80
# 12197          Poland       51
# 6198       Luxembourg       82
# 12796          France       87
# 23573          France       87
# 2443          Germany       80
# 26165          France       87
# 9865          Germany       80
# 9819   Czech Republic       54
# 920           Germany       80
# 18129         Denmark       86
# 24808          France       87
# 22089         Austria       81
# 28049          Poland       51
# 8104           France       87
# 3967          Germany       80
# 5533          Germany       80
# 18664          France       87
# 24607          Poland       51
# 15275         Germany       80

# %% [markdown]
# #  Railway station selection & filtering
#
# Let's select all stations which are big + might have access to the airport

# %%
# get cities above 200k population
# !pip install geonamescache
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting geonamescache
#   Obtaining dependency information for geonamescache from https://files.pythonhosted.org/packages/5a/49/6a6e14f4e99a29991f3446c4204c4fb28906bc07fc480ec11b0cad03ca43/geonamescache-3.0.0-py3-none-any.whl.metadata
#   Downloading geonamescache-3.0.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-extensions (from geonamescache)
#   Obtaining dependency information for typing-extensions from https://files.pythonhosted.org/packages/18/67/36e9267722cc04a6b9f15c7f3441c2363321a3ea07da7ae0c0707beb2a9c/typing_extensions-4.15.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading geonamescache-3.0.0-py3-none-any.whl (32.0 MB)
#    ---------------------------------------- 0.0/32.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.0 MB 660.6 kB/s eta 0:00:49
#    ---------------------------------------- 0.1/32.0 MB 1.3 MB/s eta 0:00:25
#    ---------------------------------------- 0.2/32.0 MB 2.0 MB/s eta 0:00:16
#    ---------------------------------------- 0.4/32.0 MB 2.2 MB/s eta 0:00:15
#     --------------------------------------- 0.5/32.0 MB 2.6 MB/s eta 0:00:13
#     --------------------------------------- 0.5/32.0 MB 2.6 MB/s eta 0:00:13
#     --------------------------------------- 0.7/32.0 MB 2.6 MB/s eta 0:00:12
#    - -------------------------------------- 0.8/32.0 MB 2.8 MB/s eta 0:00:12
#    - -------------------------------------- 0.8/32.0 MB 2.8 MB/s eta 0:00:12
#    - -------------------------------------- 1.2/32.0 MB 2.8 MB/s eta 0:00:11
#    - -------------------------------------- 1.3/32.0 MB 2.8 MB/s eta 0:00:11
#    - -------------------------------------- 1.4/32.0 MB 2.8 MB/s eta 0:00:11
#    - -------------------------------------- 1.5/32.0 MB 2.8 MB/s eta 0:00:11
#    -- ------------------------------------- 1.7/32.0 MB 2.9 MB/s eta 0:00:11
#    -- ------------------------------------- 1.8/32.0 MB 2.8 MB/s eta 0:00:11
#    -- ------------------------------------- 1.9/32.0 MB 2.8 MB/s eta 0:00:11
#    -- ------------------------------------- 2.0/32.0 MB 2.8 MB/s eta 0:00:11
#    -- ------------------------------------- 2.1/32.0 MB 2.8 MB/s eta 0:00:11
#    -- ------------------------------------- 2.2/32.0 MB 2.8 MB/s eta 0:00:11
#    -- ------------------------------------- 2.3/32.0 MB 2.8 MB/s eta 0:00:11
#    --- ------------------------------------ 2.5/32.0 MB 2.9 MB/s eta 0:00:11
#    --- ------------------------------------ 2.6/32.0 MB 2.9 MB/s eta 0:00:11
#    --- ------------------------------------ 2.7/32.0 MB 2.8 MB/s eta 0:00:11
#    --- ------------------------------------ 2.9/32.0 MB 2.9 MB/s eta 0:00:11
#    --- ------------------------------------ 3.0/32.0 MB 2.9 MB/s eta 0:00:11
#    --- ------------------------------------ 3.2/32.0 MB 2.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 3.3/32.0 MB 2.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 3.5/32.0 MB 2.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 3.6/32.0 MB 2.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 3.7/32.0 MB 3.0 MB/s eta 0:00:10
#    ---- ----------------------------------- 3.9/32.0 MB 2.9 MB/s eta 0:00:10
#    ----- ---------------------------------- 4.0/32.0 MB 2.9 MB/s eta 0:00:10
#    ----- ---------------------------------- 4.2/32.0 MB 2.9 MB/s eta 0:00:10
#    ----- ---------------------------------- 4.3/32.0 MB 2.9 MB/s eta 0:00:10
#    ----- ---------------------------------- 4.4/32.0 MB 3.0 MB/s eta 0:00:10
#    ----- ---------------------------------- 4.6/32.0 MB 3.0 MB/s eta 0:00:10
#    ----- ---------------------------------- 4.7/32.0 MB 3.0 MB/s eta 0:00:10
#    ------ --------------------------------- 4.9/32.0 MB 3.0 MB/s eta 0:00:10
#    ------ --------------------------------- 5.1/32.0 MB 3.0 MB/s eta 0:00:09
#    ------ --------------------------------- 5.2/32.0 MB 3.0 MB/s eta 0:00:09
#    ------ --------------------------------- 5.3/32.0 MB 3.0 MB/s eta 0:00:09
#    ------ --------------------------------- 5.5/32.0 MB 3.0 MB/s eta 0:00:09
#    ------- -------------------------------- 5.6/32.0 MB 3.1 MB/s eta 0:00:09
#    ------- -------------------------------- 5.8/32.0 MB 3.0 MB/s eta 0:00:09
#    ------- -------------------------------- 6.0/32.0 MB 3.0 MB/s eta 0:00:09
#    ------- -------------------------------- 6.1/32.0 MB 3.0 MB/s eta 0:00:09
#    ------- -------------------------------- 6.2/32.0 MB 3.0 MB/s eta 0:00:09
#    ------- -------------------------------- 6.3/32.0 MB 3.0 MB/s eta 0:00:09
#    -------- ------------------------------- 6.5/32.0 MB 3.0 MB/s eta 0:00:09
#    -------- ------------------------------- 6.6/32.0 MB 3.0 MB/s eta 0:00:09
#    -------- ------------------------------- 6.8/32.0 MB 3.1 MB/s eta 0:00:09
#    -------- ------------------------------- 6.9/32.0 MB 3.0 MB/s eta 0:00:09
#    -------- ------------------------------- 7.0/32.0 MB 3.0 MB/s eta 0:00:09
#    -------- ------------------------------- 7.2/32.0 MB 3.0 MB/s eta 0:00:09
#    --------- ------------------------------ 7.3/32.0 MB 3.0 MB/s eta 0:00:09
#    --------- ------------------------------ 7.5/32.0 MB 3.0 MB/s eta 0:00:09
#    --------- ------------------------------ 7.7/32.0 MB 3.1 MB/s eta 0:00:08
#    --------- ------------------------------ 7.8/32.0 MB 3.1 MB/s eta 0:00:08
#    --------- ------------------------------ 8.0/32.0 MB 3.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 8.2/32.0 MB 3.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 8.3/32.0 MB 3.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 8.4/32.0 MB 3.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 8.6/32.0 MB 3.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 8.7/32.0 MB 3.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 8.9/32.0 MB 3.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 9.0/32.0 MB 3.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 9.2/32.0 MB 3.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 9.3/32.0 MB 3.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 9.5/32.0 MB 3.1 MB/s eta 0:00:08
#    ----------- ---------------------------- 9.6/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------ --------------------------- 9.7/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------ --------------------------- 9.8/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------ --------------------------- 9.9/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------ --------------------------- 10.0/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------ --------------------------- 10.1/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------ --------------------------- 10.2/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------ --------------------------- 10.3/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------- -------------------------- 10.5/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------- -------------------------- 10.6/32.0 MB 3.0 MB/s eta 0:00:08
#    ------------- -------------------------- 10.8/32.0 MB 3.1 MB/s eta 0:00:07
#    ------------- -------------------------- 10.9/32.0 MB 3.0 MB/s eta 0:00:07
#    ------------- -------------------------- 11.1/32.0 MB 3.1 MB/s eta 0:00:07
#    -------------- ------------------------- 11.3/32.0 MB 3.0 MB/s eta 0:00:07
#    -------------- ------------------------- 11.4/32.0 MB 3.0 MB/s eta 0:00:07
#    -------------- ------------------------- 11.5/32.0 MB 3.0 MB/s eta 0:00:07
#    -------------- ------------------------- 11.7/32.0 MB 3.0 MB/s eta 0:00:07
#    -------------- ------------------------- 11.8/32.0 MB 3.0 MB/s eta 0:00:07
#    --------------- ------------------------ 12.0/32.0 MB 3.0 MB/s eta 0:00:07
#    --------------- ------------------------ 12.2/32.0 MB 3.0 MB/s eta 0:00:07
#    --------------- ------------------------ 12.3/32.0 MB 3.0 MB/s eta 0:00:07
#    --------------- ------------------------ 12.5/32.0 MB 3.1 MB/s eta 0:00:07
#    --------------- ------------------------ 12.6/32.0 MB 3.0 MB/s eta 0:00:07
#    --------------- ------------------------ 12.7/32.0 MB 3.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 12.9/32.0 MB 3.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 13.1/32.0 MB 3.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 13.2/32.0 MB 3.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 13.3/32.0 MB 3.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 13.5/32.0 MB 3.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 13.6/32.0 MB 3.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 13.8/32.0 MB 3.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 13.9/32.0 MB 3.0 MB/s eta 0:00:06
#    ----------------- ---------------------- 14.0/32.0 MB 3.0 MB/s eta 0:00:06
#    ----------------- ---------------------- 14.2/32.0 MB 3.0 MB/s eta 0:00:06
#    ----------------- ---------------------- 14.3/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------ --------------------- 14.5/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------ --------------------- 14.6/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------ --------------------- 14.8/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------ --------------------- 14.9/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------ --------------------- 15.0/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------- -------------------- 15.2/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------- -------------------- 15.3/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------- -------------------- 15.5/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------- -------------------- 15.6/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------- -------------------- 15.8/32.0 MB 3.0 MB/s eta 0:00:06
#    ------------------- -------------------- 16.0/32.0 MB 3.0 MB/s eta 0:00:06
#    -------------------- ------------------- 16.1/32.0 MB 3.0 MB/s eta 0:00:06
#    -------------------- ------------------- 16.3/32.0 MB 3.0 MB/s eta 0:00:06
#    -------------------- ------------------- 16.4/32.0 MB 3.0 MB/s eta 0:00:06
#    -------------------- ------------------- 16.5/32.0 MB 3.0 MB/s eta 0:00:06
#    -------------------- ------------------- 16.7/32.0 MB 3.0 MB/s eta 0:00:06
#    --------------------- ------------------ 16.9/32.0 MB 3.0 MB/s eta 0:00:06
#    --------------------- ------------------ 17.0/32.0 MB 3.0 MB/s eta 0:00:05
#    --------------------- ------------------ 17.2/32.0 MB 3.0 MB/s eta 0:00:05
#    --------------------- ------------------ 17.3/32.0 MB 3.0 MB/s eta 0:00:05
#    --------------------- ------------------ 17.4/32.0 MB 3.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 17.6/32.0 MB 3.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 17.7/32.0 MB 3.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 17.9/32.0 MB 3.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 18.1/32.0 MB 3.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 18.2/32.0 MB 3.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 18.3/32.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 18.5/32.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 18.6/32.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 18.7/32.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 18.9/32.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 19.0/32.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------- ---------------- 19.1/32.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------ --------------- 19.3/32.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------ --------------- 19.4/32.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------ --------------- 19.5/32.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------ --------------- 19.7/32.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------ --------------- 19.9/32.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------- -------------- 20.0/32.0 MB 3.0 MB/s eta 0:00:04
#    ------------------------- -------------- 20.2/32.0 MB 3.0 MB/s eta 0:00:04
#    ------------------------- -------------- 20.3/32.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------- -------------- 20.5/32.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------- -------------- 20.7/32.0 MB 3.1 MB/s eta 0:00:04
#    -------------------------- ------------- 20.8/32.0 MB 3.1 MB/s eta 0:00:04
#    -------------------------- ------------- 21.0/32.0 MB 3.1 MB/s eta 0:00:04
#    -------------------------- ------------- 21.1/32.0 MB 3.1 MB/s eta 0:00:04
#    -------------------------- ------------- 21.3/32.0 MB 3.1 MB/s eta 0:00:04
#    -------------------------- ------------- 21.4/32.0 MB 3.1 MB/s eta 0:00:04
#    -------------------------- ------------- 21.5/32.0 MB 3.1 MB/s eta 0:00:04
#    --------------------------- ------------ 21.6/32.0 MB 3.0 MB/s eta 0:00:04
#    --------------------------- ------------ 21.7/32.0 MB 3.0 MB/s eta 0:00:04
#    --------------------------- ------------ 21.9/32.0 MB 3.0 MB/s eta 0:00:04
#    --------------------------- ------------ 22.0/32.0 MB 3.0 MB/s eta 0:00:04
#    --------------------------- ------------ 22.2/32.0 MB 3.0 MB/s eta 0:00:04
#    --------------------------- ------------ 22.3/32.0 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 22.4/32.0 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 22.5/32.0 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 22.7/32.0 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 22.8/32.0 MB 3.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 23.0/32.0 MB 3.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 23.2/32.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 23.3/32.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 23.4/32.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 23.6/32.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 23.7/32.0 MB 3.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 23.8/32.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------------ --------- 24.0/32.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------------ --------- 24.1/32.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------------ --------- 24.2/32.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------------ --------- 24.4/32.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------------ --------- 24.5/32.0 MB 3.0 MB/s eta 0:00:03
#    ------------------------------ --------- 24.7/32.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 24.8/32.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 25.0/32.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 25.1/32.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 25.3/32.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 25.4/32.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 25.5/32.0 MB 3.1 MB/s eta 0:00:03
#    -------------------------------- ------- 25.7/32.0 MB 3.1 MB/s eta 0:00:03
#    -------------------------------- ------- 25.8/32.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 26.0/32.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 26.1/32.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 26.2/32.0 MB 3.1 MB/s eta 0:00:02
#    -------------------------------- ------- 26.4/32.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 26.5/32.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 26.7/32.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 26.8/32.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 27.0/32.0 MB 3.1 MB/s eta 0:00:02
#    --------------------------------- ------ 27.1/32.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 27.3/32.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 27.4/32.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 27.5/32.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 27.7/32.0 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 27.9/32.0 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 28.0/32.0 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 28.2/32.0 MB 3.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 28.3/32.0 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 28.5/32.0 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 28.6/32.0 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 28.8/32.0 MB 3.1 MB/s eta 0:00:02
#    ------------------------------------ --- 28.9/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 29.1/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 29.2/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 29.3/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------ --- 29.5/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 29.6/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 29.8/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 29.9/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 30.1/32.0 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 30.2/32.0 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 30.4/32.0 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 30.5/32.0 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 30.6/32.0 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 30.6/32.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 30.6/32.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 30.6/32.0 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 30.6/32.0 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 30.7/32.0 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 30.7/32.0 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 30.7/32.0 MB 2.9 MB/s eta 0:00:01
#    -------------------------------------- - 30.7/32.0 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 30.7/32.0 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 30.9/32.0 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 31.0/32.0 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 31.1/32.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  31.2/32.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  31.4/32.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  31.5/32.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  31.6/32.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  31.7/32.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  31.8/32.0 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 32.0/32.0 MB 2.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.6 kB ? eta -:--:--
#    ---------------------------------------- 44.6/44.6 kB ? eta 0:00:00
# Installing collected packages: typing-extensions, geonamescache
# Successfully installed geonamescache-3.0.0 typing-extensions-4.15.0
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import geonamescache

gc = geonamescache.GeonamesCache()
cities = gc.get_cities()
CITIES_300K = []

countries = gc.get_countries()
ALLOWED_COUNTRIES = {}
for code, info in countries.items():
    if info['continentcode'] == 'EU' and info["name"] in ALLOWED_UIC_PREFIXES.values():
        ALLOWED_COUNTRIES[code] = info["name"]

cities
# Out:
# {'3040051': {'geonameid': 3040051,
#   'name': 'les Escaldes',
#   'latitude': 42.50729,
#   'longitude': 1.53414,
#   'countrycode': 'AD',
#   'population': 15853,
#   'timezone': 'Europe/Andorra',
#   'admin1code': '08',
#   'alternatenames': ["Ehskal'des-Ehndzhordani",
#    'Escaldes',
#    'Escaldes-Engordany',
#    'Les Escaldes',
#    'esukarudesu=engorudani jiao qu',
#    'lai sai si ka er de-en ge er da',
#    'Эскальдес-Энджордани',
#    'エスカルデス＝エンゴルダニ教区',
#    '萊塞斯卡爾德-恩戈爾達',
#    '萊塞斯卡爾德－恩戈爾達']},
#  '3041563': {'geonameid': 3041563,
#   'name': 'Andorra la Vella',
#   'latitude': 42.50779,
#   'longitude': 1.52109,
#   'countrycode': 'AD',
#   'population': 20430,
#   'timezone': 'Europe/Andorra',
#   'admin1code': '07',
#   'alternatenames': ['ALV',
#    'Ando-la-Vyey',
#    'Andora',
#    'Andora la Vela',
#    'Andora la Velja',
#    "Andora lja Vehl'ja",
#    'Andoro Malnova',
#    'Andorra',
#    'Andorra Tuan',
#    'Andorra a Vella',
#    'Andorra la Biella',
#    'Andorra la Vella',
#    'Andorra la Vielha',
#    'Andorra-a-Velha',
#    "Andorra-la-Vel'ja",
#    'Andorra-la-Vielye',
#    'Andorre-la-Vieille',
#    'Andò-la-Vyèy',
#    'Andòrra la Vièlha',
#    'an dao er cheng',
#    'andolalabeya',
#    'andwra la fyla',
#    'Ανδόρρα',
#    'Андора ла Веля',
#    'Андора ла Веља',
#    'Андора ля Вэлья',
#    'Андорра-ла-Велья',
#    'אנדורה לה וולה',
#    'أندورا لا فيلا',
#    'አንዶራ ላ ቬላ',
#    'アンドラ・ラ・ヴェリャ',
#    '安道爾城',
#    '안도라라베야']},
#  '290503': {'geonameid': 290503,
#   'name': 'Warīsān',
#   'latitude': 25.16744,
#   'longitude': 55.40708,
#   'countrycode': 'AE',
#   'population': 108759,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Warisan', 'Warsan', 'Warīsān', 'wrsan', 'ورسان']},
#  '290581': {'geonameid': 290581,
#   'name': 'Umm Suqaym',
#   'latitude': 25.15491,
#   'longitude': 55.21015,
#   'countrycode': 'AE',
#   'population': 16459,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Umm Suqaym',
#    'Umm Suqeim',
#    'Umm Suqeim 2',
#    'Umm as Suqaym',
#    'am sqym',
#    'أم سقيم']},
#  '290594': {'geonameid': 290594,
#   'name': 'Umm Al Quwain City',
#   'latitude': 25.56473,
#   'longitude': 55.55517,
#   'countrycode': 'AE',
#   'population': 59098,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '07',
#   'alternatenames': ['Oumm al Qaiwain',
#    'Oumm al Qaïwaïn',
#    'Um al Kawain',
#    'Um al Quweim',
#    'Umm Al Quwain City',
#    'Umm al Qaiwain',
#    'Umm al Qawain',
#    'Umm al Qaywayn',
#    'Umm al-Quwain',
#    "Umm-ehl'-Kajvajn",
#    'Yumul al Quwain',
#    'am alqywyn',
#    'mdynt am alqywyn',
#    'Умм-эль-Кайвайн',
#    'أم القيوين',
#    'مدينة ام القيوين']},
#  '290680': {'geonameid': 290680,
#   'name': 'Ţarīf Kalbā',
#   'latitude': 25.0695,
#   'longitude': 56.33115,
#   'countrycode': 'AE',
#   'population': 51000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Tarif Kalba', 'Ţarīf Kalbā']},
#  '291061': {'geonameid': 291061,
#   'name': 'Ar Rāshidīyah',
#   'latitude': 25.22499,
#   'longitude': 55.38947,
#   'countrycode': 'AE',
#   'population': 38425,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Rashidiya',
#    'Ar Rashidiyah',
#    'Ar Rāshidīyah',
#    'Rashdia',
#    'Rashidiyah',
#    'Rashīdīyah',
#    'alrashdyt',
#    'الراشدية']},
#  '291074': {'geonameid': 291074,
#   'name': 'Ras Al Khaimah City',
#   'latitude': 25.78953,
#   'longitude': 55.9432,
#   'countrycode': 'AE',
#   'population': 351943,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '05',
#   'alternatenames': ['Julfa',
#    'Khaimah',
#    'RAK City',
#    'RKT',
#    "Ra's al Khaymah",
#    "Ra's al-Chaima",
#    'Ras Al Khaimah City',
#    'Ras al Khaimah',
#    'Ras al-Khaimah',
#    'Ras el Khaimah',
#    'Ras el Khaïmah',
#    'Ras el-Kheima',
#    "Ras-ehl'-Khajma",
#    'Ra’s al Khaymah',
#    'Ra’s al-Chaima',
#    'mdynt ras alkhymt',
#    'ras alkhymt',
#    'Рас-эль-Хайма',
#    'رأس الخيمة',
#    'مدينة رأس الخيمة']},
#  '291580': {'geonameid': 291580,
#   'name': 'Zayed City',
#   'latitude': 23.65416,
#   'longitude': 53.70522,
#   'countrycode': 'AE',
#   'population': 63482,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ["Bid' Zayed",
#    'Bid’ Zayed',
#    "Madinat Za'id",
#    'Madinat Zayid',
#    'Madīnat Zāyid',
#    'Madīnat Zā’id',
#    'Zayed City',
#    'mdynt zayd',
#    'مدينة زايد']},
#  '291696': {'geonameid': 291696,
#   'name': 'Khawr Fakkān',
#   'latitude': 25.33132,
#   'longitude': 56.34199,
#   'countrycode': 'AE',
#   'population': 40677,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Fakkan',
#    'Fakkān',
#    'Khawr Fakkan',
#    'Khawr Fakkān',
#    'Khawr al Fakkan',
#    'Khawr al Fakkān',
#    'Khor Fakhan',
#    'Khor Fakkan',
#    'Khor Fakkan City',
#    'Khor Fakkān',
#    'Khor al Fakhan',
#    'Khor al Fakkan',
#    'Khor al Fākhān',
#    "Khor'fakkan",
#    'Khor-Fakkan',
#    'Khorfakan',
#    'Khorfakhan',
#    'Port Khor Fakkan',
#    'mdynt khwr fkan',
#    'Хор-Факкан',
#    'مدينة خور فكان']},
#  '291763': {'geonameid': 291763,
#   'name': 'Kalbā',
#   'latitude': 25.0513,
#   'longitude': 56.35422,
#   'countrycode': 'AE',
#   'population': 37545,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Ghalla',
#    'Ghallah',
#    'Ghālla',
#    'Ghāllah',
#    'Kalba',
#    'Kalbah',
#    'Kalbā',
#    'Qalba']},
#  '291775': {'geonameid': 291775,
#   'name': 'Jumayrā',
#   'latitude': 25.20795,
#   'longitude': 55.24969,
#   'countrycode': 'AE',
#   'population': 39080,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Jimeirah',
#    'Jumaira',
#    'Jumairah',
#    'Jumayra',
#    'Jumayrah',
#    'Jumayrā',
#    'Jumeira',
#    'Jumeirah',
#    'jmyra',
#    'جميرا']},
#  '292223': {'geonameid': 292223,
#   'name': 'Dubai',
#   'latitude': 25.07725,
#   'longitude': 55.30927,
#   'countrycode': 'AE',
#   'population': 3790000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['DXB',
#    'Dabei',
#    'Dibai',
#    'Dibay',
#    'Doubayi',
#    'Dubae',
#    'Dubai',
#    'Dubai City',
#    'Dubai emiraat',
#    'Dubaija',
#    'Dubaj',
#    'Dubajo',
#    'Dubajus',
#    'Dubay',
#    'Dubayy',
#    'Dubaï',
#    'Dubái',
#    'Dúbæ',
#    'Fort Dabei',
#    'Ntoumpai',
#    'dby',
#    'dbyy',
#    'di bai',
#    'dobai',
#    'du bai',
#    "duba'i",
#    'dubai',
#    'dubay',
#    'dubi',
#    'dwbyy',
#    'tupai',
#    'Ντουμπάι',
#    'Дубаи',
#    'Дубай',
#    'Դուբայ',
#    'דובאי',
#    'דוביי',
#    'دبئی',
#    'دبى',
#    'دبي',
#    'دبی',
#    'دوبەی',
#    'دۇبائى',
#    'दुबई',
#    'দুবাই',
#    'துபை',
#    'దుబాయ్',
#    'ದುಬೈ',
#    'ദുബായ്',
#    'ดูไบ',
#    'დუბაი',
#    'ドバイ',
#    '杜拜',
#    '迪拜',
#    '두바이']},
#  '292231': {'geonameid': 292231,
#   'name': 'Dibba Al-Fujairah',
#   'latitude': 25.59246,
#   'longitude': 56.26176,
#   'countrycode': 'AE',
#   'population': 30000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Al-Fujairah',
#    'BYB',
#    'Dibba Al-Fujairah',
#    'dba alfjyrt',
#    'دبا الفجيرة']},
#  '292239': {'geonameid': 292239,
#   'name': 'Dibba Al-Hisn',
#   'latitude': 25.61955,
#   'longitude': 56.27291,
#   'countrycode': 'AE',
#   'population': 26395,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['BYB',
#    'Daba',
#    'Daba al-Hisn',
#    'Dabā',
#    'Dabā al-Ḥiṣn',
#    'Diba',
#    'Diba Al Hisn',
#    'Diba al Hisn',
#    'Dibah',
#    'Dibba',
#    'Dibba Al Hisn',
#    "Dibba Al'-Khisn",
#    'Dibba Al-Hisn',
#    'Dibbah',
#    'Dibbā Al Ḩişn',
#    'Dibā',
#    'Dibā Al Ḩişn',
#    'Dībā al Ḩişn',
#    'Hisn Diba',
#    'Husn Dibba',
#    'Дибба Аль-Хисн',
#    'Ḩişn Dibā']},
#  '292261': {'geonameid': 292261,
#   'name': 'Dayrah',
#   'latitude': 25.27143,
#   'longitude': 55.30207,
#   'countrycode': 'AE',
#   'population': 400000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Daira',
#    'Dairah',
#    'Dayrah',
#    'Deira',
#    'Dirah',
#    'Dīrah',
#    'dyrt',
#    'ديرة']},
#  '292672': {'geonameid': 292672,
#   'name': 'Sharjah',
#   'latitude': 25.33737,
#   'longitude': 55.41206,
#   'countrycode': 'AE',
#   'population': 1800000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Al Sharjah',
#    "Ash 'Mariqah",
#    'Ash Shariqa',
#    'Ash Shariqah',
#    'Ash Shāriqa',
#    'Ash Shāriqah',
#    'Ash ’Mariqah',
#    'Ash-Shariqah emiraat',
#    'Ash-Shāriqah emiraat',
#    'Charjah',
#    'Ch·ardj·a',
#    'SHJ',
#    'Sardza',
#    'Sardzsa',
#    'Sarika',
#    'Sarja',
#    'Sarjo',
#    'Sarza',
#    'Schardscha',
#    'Shardza',
#    'Shardzha',
#    'Shardzha kuorat',
#    'Sharga',
#    'Sharijah',
#    'Shariqah',
#    'Sharja',
#    'Sharjah',
#    'Sharjah city',
#    'Shārijah',
#    'Shāriqah',
#    'Shārja',
#    'Szardza',
#    'Szardża',
#    'Xarja',
#    'Xarjah',
#    'alsharqt',
#    'amart alsharqt',
#    'carja',
#    'charc ah',
#    'mdynt alsharqt',
#    'saraja',
#    'sarajaha',
#    'sarja',
#    'sharja',
#    'sharjh',
#    'sharuja',
#    'syaleuja',
#    'sʼrgh',
#    'xia er jia',
#    'Ŝarĵo',
#    'Şarika',
#    'Şarja',
#    'Šardža',
#    'Šardžá',
#    'Шарджа',
#    'Шарджа куорат',
#    'Шарџа',
#    'Шарҗә',
#    'Շարժա',
#    'שארגה',
#    'إمارة الشارقة',
#    'الشارقة',
#    'شارجه',
#    'شارجہ',
#    'مدينة الشارقة',
#    'शारजा',
#    'शारजाह',
#    'ਸ਼ਾਰਜਾ',
#    'சார்ஜா',
#    'షార్జా',
#    'ಶಾರ್ಜ',
#    'ഷാർജ',
#    'ชาร์จาห์',
#    'შარჯა',
#    'シャールジャ',
#    '夏尔迦',
#    '샤르자']},
#  '292688': {'geonameid': 292688,
#   'name': 'Ar Ruways',
#   'latitude': 24.11028,
#   'longitude': 52.73056,
#   'countrycode': 'AE',
#   'population': 25000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ["Ar Ru'ays",
#    'Ar Ruways',
#    'Ar Ru’ays',
#    'Ar-Ruvais',
#    'Ruwais',
#    'alrwys',
#    'ar-Ruways',
#    'lu wa si',
#    'ruvais',
#    'Ар-Руваис',
#    'الرويس',
#    'الرویس',
#    'റുവൈസ്',
#    '魯瓦斯',
#    '鲁瓦斯']},
#  '292862': {'geonameid': 292862,
#   'name': 'Ḩattā',
#   'latitude': 24.80073,
#   'longitude': 56.12726,
#   'countrycode': 'AE',
#   'population': 15324,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Hagarein',
#    'Al Hajarayn',
#    'Al Ḥagarein',
#    'Al Ḩajarayn',
#    'Hajarain',
#    'Hajarayn',
#    'Hajrain',
#    'Hatta',
#    'hta',
#    'حتا',
#    'Ḩajarayn',
#    'Ḩattā']},
#  '292878': {'geonameid': 292878,
#   'name': 'Al Fujairah City',
#   'latitude': 25.11641,
#   'longitude': 56.34141,
#   'countrycode': 'AE',
#   'population': 118933,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Al Fujairah City',
#    'Al Fujayrah',
#    'Al-Fudjayra',
#    "Al-Fujayrah' emiraat",
#    'FJR',
#    'Fudschaira',
#    'Fudzhejra',
#    'Fujaira',
#    'Fujairah',
#    'Fujajro',
#    'Fujayrah',
#    'Fuĵajro',
#    'alfjyrt',
#    'fjyrt',
#    'fu ji la',
#    'fujaira',
#    'mdynt alfjyrt',
#    'Фуджейра',
#    'الفجيرة',
#    'فجيرة',
#    'مدينة الفجيرة',
#    'フジャイラ',
#    '富吉拉']},
#  '292913': {'geonameid': 292913,
#   'name': 'Al Ain City',
#   'latitude': 24.19167,
#   'longitude': 55.76056,
#   'countrycode': 'AE',
#   'population': 846747,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['AAN',
#    'Ainas',
#    'Al Ain',
#    'Al Ain City',
#    'Al Ajn',
#    'Al Ayn',
#    'Al `Ayn',
#    'Al Ɛayn',
#    'Al ‘Ayn',
#    'Al-Ain',
#    'Al-Ajn',
#    'Al-Ayin',
#    'Al-Ayn',
#    'Al-Aïn',
#    "Ehl'-Ajn",
#    'El Ain',
#    'El-Ajn',
#    'ai yin',
#    'al ain',
#    'al-ain',
#    'al-aini',
#    'alʿyn',
#    'ela ena',
#    'mdynt alʿyn',
#    'Ел Аин',
#    'Эль-Айн',
#    'Ալ-Ային',
#    'אל-עין',
#    'العين',
#    'العین',
#    'مدينة العين',
#    'एल एन',
#    'அல் ஐன்',
#    'അൽ ഐൻ',
#    'ალ-აინი',
#    'アル・アイン',
#    '艾因',
#    '알아인']},
#  '292932': {'geonameid': 292932,
#   'name': 'Ajman City',
#   'latitude': 25.40177,
#   'longitude': 55.47878,
#   'countrycode': 'AE',
#   'population': 490035,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Ajman',
#    'Ajman City',
#    'Al Ajman',
#    'QAJ',
#    'Ujman',
#    'mdynt ʿjman',
#    'ʿjman',
#    'عجمان',
#    'مدينة عجمان']},
#  '292953': {'geonameid': 292953,
#   'name': 'Adh Dhayd',
#   'latitude': 25.28812,
#   'longitude': 55.88157,
#   'countrycode': 'AE',
#   'population': 20165,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['Adh Dhaid',
#    'Adh Dhayd',
#    'Adh Dhed',
#    'Adh Dhēd',
#    'Al Daid',
#    'Al-Dhayd',
#    'Az-Zajd',
#    'Dayd',
#    'Dhaid',
#    'Dhayd',
#    'Duhayd',
#    'Ehd-Dajd',
#    'Ihaid',
#    'Zeyd',
#    'adh-Dhayd',
#    'aldhyd',
#    'da yi de',
#    'daid',
#    'dhyd',
#    'Эд-Дайд',
#    'الذيد',
#    'ذید',
#    'ദൈദ്',
#    'Ḑayd',
#    '達伊德']},
#  '292968': {'geonameid': 292968,
#   'name': 'Abu Dhabi',
#   'latitude': 24.45118,
#   'longitude': 54.39696,
#   'countrycode': 'AE',
#   'population': 1807000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['A-pu-that-pi',
#    'AEbu Saby',
#    'AUH',
#    'Aboe Dhabi',
#    'Abou Dabi',
#    'Abu Dabi',
#    'Abu Dabis',
#    'Abu Daby',
#    'Abu Daibi',
#    'Abu Dhabi',
#    'Abu Dhabi Island and Internal Islands City',
#    'Abu Dhabi emiraat',
#    'Abu Zabi',
#    'Abu Zaby',
#    'Abu Zabye',
#    'Abu Zabyo',
#    'Abu Ḍabi',
#    'Abu Ḑabi',
#    'Abu-Dabi',
#    'Abu-Dabi khot',
#    'Abu-Dabio',
#    'Abu-Dzabi',
#    'Abú Dabí',
#    'Abú Daibí',
#    'Abú Zabí',
#    'Abû Daby',
#    'Abū Dabī',
#    'Abū Z̧aby',
#    'Abū Z̧abye',
#    'Abū Z̧abyo',
#    'Abū Z̧abī',
#    'Ampou Ntampi',
#    'Ebu Dabi',
#    'Ebu Dhabi',
#    'a bu zha bi',
#    'abu dhabi',
#    'abu-dabi',
#    'abudabi',
#    'abudhabi',
#    'abw zby',
#    'abwzby',
#    'aputapi',
#    'jzyrt abwzby wjzr dakhlyt akhry',
#    'xa bud abi',
#    'Â-pu-tha̍t-pí',
#    'Äbu Saby',
#    'Əbu-Dabi',
#    'Άμπου Ντάμπι',
#    'Αμπου Νταμπι',
#    'Αμπού Ντάμπι',
#    'Абу Даби',
#    'Абу-Даби',
#    'Абу-Даби хот',
#    'Абу-Дабі',
#    'Әбу-Даби',
#    'Աբու Դաբի',
#    'אבו דאבי',
#    'أبوظبي',
#    'ئەبووزەبی',
#    'ابو ظبى',
#    'ابوظبی',
#    'ابوظہبی',
#    'جزيرة أبوظبي وجزر داخلية اخرى',
#    'अबु धाबी',
#    'अबू धाबी',
#    'আবুধাবি',
#    'ਅਬੂ ਧਾਬੀ',
#    'ଆବୁଧାବି',
#    'அபுதாபி',
#    'ಅಬು ಧಾಬಿ',
#    'അബുദാബി',
#    'අබුඩාබි',
#    'อาบูดาบี',
#    'ཨ་པོའུ་དྷ་པེ།',
#    'အဘူဒါဘီမြို့',
#    'აბუ-დაბი',
#    'አቡ ዳቢ',
#    'アブダビ',
#    '阿布扎比',
#    '아부다비']},
#  '292991': {'geonameid': 292991,
#   'name': 'Abū Hayl',
#   'latitude': 25.28413,
#   'longitude': 55.33153,
#   'countrycode': 'AE',
#   'population': 18043,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Abu Hail', 'Hail', 'Hāil']},
#  '385024': {'geonameid': 385024,
#   'name': 'As Saţwah',
#   'latitude': 25.22192,
#   'longitude': 55.27459,
#   'countrycode': 'AE',
#   'population': 40997,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Satwa',
#    'As Satwah',
#    'As Saţwah',
#    'Satwa',
#    'alstwh',
#    'السطوه']},
#  '414901': {'geonameid': 414901,
#   'name': 'Al Ḩamīdīyah',
#   'latitude': 25.40001,
#   'longitude': 55.52925,
#   'countrycode': 'AE',
#   'population': 27000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Al Hamidiyah', 'Al Ḩamīdīyah', 'alhmydyt', 'الحميدية']},
#  '6691079': {'geonameid': 6691079,
#   'name': 'Al Waheda',
#   'latitude': 25.29173,
#   'longitude': 55.33822,
#   'countrycode': 'AE',
#   'population': 21608,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '6691091': {'geonameid': 6691091,
#   'name': 'Al Karama',
#   'latitude': 25.24004,
#   'longitude': 55.30106,
#   'countrycode': 'AE',
#   'population': 75560,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '6691113': {'geonameid': 6691113,
#   'name': 'The Palm Jumeirah',
#   'latitude': 25.11607,
#   'longitude': 55.13506,
#   'countrycode': 'AE',
#   'population': 25500,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Palm Jumeirah', 'nkhlt aljmyrt', 'نخلة الجميرة']},
#  '7289825': {'geonameid': 7289825,
#   'name': 'Bur Dubai',
#   'latitude': 25.26038,
#   'longitude': 55.29891,
#   'countrycode': 'AE',
#   'population': 18698,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['br dby', 'بر دبي']},
#  '8057551': {'geonameid': 8057551,
#   'name': 'Khalifah A City',
#   'latitude': 24.42588,
#   'longitude': 54.605,
#   'countrycode': 'AE',
#   'population': 85374,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Khalifah A City',
#    'Madinat Khalifah A',
#    'Madīnat Khalīfah A',
#    'mdynt khlyft a',
#    'mdynt khlyft a/ mtar abwzby aldwly',
#    'مدينة خليفة أ',
#    'مدينة خليفة أ/ مطار أبوظبي الدولي']},
#  '8200824': {'geonameid': 8200824,
#   'name': 'Mirdif',
#   'latitude': 25.22443,
#   'longitude': 55.41412,
#   'countrycode': 'AE',
#   'population': 60288,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Mirdif', 'mrdf', 'مردف']},
#  '8201275': {'geonameid': 8201275,
#   'name': 'Hawr al ‘Anz',
#   'latitude': 25.27744,
#   'longitude': 55.33675,
#   'countrycode': 'AE',
#   'population': 84661,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Hawr al `Anz',
#    'Hawr al ‘Anz',
#    'Hor al Anz',
#    'هور العنز']},
#  '8225407': {'geonameid': 8225407,
#   'name': 'Mankhūl',
#   'latitude': 25.24612,
#   'longitude': 55.29222,
#   'countrycode': 'AE',
#   'population': 41244,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Mankhool',
#    'Mankhool',
#    'Mankhul',
#    'Mankhūl',
#    'mnkhwl',
#    'منخول']},
#  '8226485': {'geonameid': 8226485,
#   'name': 'Nāyf',
#   'latitude': 25.27139,
#   'longitude': 55.30323,
#   'countrycode': 'AE',
#   'population': 53075,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Naif', 'Nayf', 'Nāyf', 'nayf', 'نايف']},
#  '8226590': {'geonameid': 8226590,
#   'name': 'Al Murar al Qadīm',
#   'latitude': 25.27576,
#   'longitude': 55.30738,
#   'countrycode': 'AE',
#   'population': 19831,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Murar',
#    'Al Murar al Qadeem',
#    'Al Murar al Qadim',
#    'Al Murar al Qadīm',
#    'almrr alqdym',
#    'المرر القديم']},
#  '8469658': {'geonameid': 8469658,
#   'name': 'Al Warqaa',
#   'latitude': 25.19272,
#   'longitude': 55.42013,
#   'countrycode': 'AE',
#   'population': 59111,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Warqaa']},
#  '8469668': {'geonameid': 8469668,
#   'name': 'International City',
#   'latitude': 25.16383,
#   'longitude': 55.40987,
#   'countrycode': 'AE',
#   'population': 120000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Dubai International City', 'International City']},
#  '8469788': {'geonameid': 8469788,
#   'name': 'Dubai Marina',
#   'latitude': 25.08525,
#   'longitude': 55.14646,
#   'countrycode': 'AE',
#   'population': 120000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Dubai Marina',
#    'Dubaj Marina',
#    'Dubaja Jakthaveno',
#    'Dubaï Marina',
#    'Marina de Dubai',
#    'Marina de Dubái',
#    'dby maryna',
#    'dobaimarina',
#    'dubai marina',
#    'mrsy dby',
#    'Дубай Марина',
#    'دبی مارینا',
#    'مرسى دبي',
#    'დუბაი მარინა',
#    'ドバイマリーナ']},
#  '8469811': {'geonameid': 8469811,
#   'name': 'Dubai Internet City',
#   'latitude': 25.09538,
#   'longitude': 55.16171,
#   'countrycode': 'AE',
#   'population': 24000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Dubai Internet City']},
#  '8469819': {'geonameid': 8469819,
#   'name': 'Al Safa',
#   'latitude': 25.17047,
#   'longitude': 55.23336,
#   'countrycode': 'AE',
#   'population': 15672,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Safa']},
#  '8475866': {'geonameid': 8475866,
#   'name': 'Ar Rumaylah',
#   'latitude': 25.40338,
#   'longitude': 55.4334,
#   'countrycode': 'AE',
#   'population': 86000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Ar Rumaylah', 'alrmylt', 'الرميلة']},
#  '8475923': {'geonameid': 8475923,
#   'name': 'Al Jurf',
#   'latitude': 25.41814,
#   'longitude': 55.50791,
#   'countrycode': 'AE',
#   'population': 18000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '02',
#   'alternatenames': ['Al Jurf', 'aljrf', 'الجرف']},
#  '8476509': {'geonameid': 8476509,
#   'name': 'Al Majaz',
#   'latitude': 25.32354,
#   'longitude': 55.38774,
#   'countrycode': 'AE',
#   'population': 116503,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['']},
#  '8541937': {'geonameid': 8541937,
#   'name': 'Dubai Festival City',
#   'latitude': 25.22177,
#   'longitude': 55.35733,
#   'countrycode': 'AE',
#   'population': 77000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '8541977': {'geonameid': 8541977,
#   'name': 'Dubai International Financial Centre',
#   'latitude': 25.2106,
#   'longitude': 55.27787,
#   'countrycode': 'AE',
#   'population': 36000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '11048853': {'geonameid': 11048853,
#   'name': 'Dubai Investments Park',
#   'latitude': 25.00827,
#   'longitude': 55.15682,
#   'countrycode': 'AE',
#   'population': 160000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '11524601': {'geonameid': 11524601,
#   'name': 'Jebel Ali',
#   'latitude': 25.00255,
#   'longitude': 55.10811,
#   'countrycode': 'AE',
#   'population': 210000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['jbl ʿly', 'جبل علي']},
#  '12042052': {'geonameid': 12042052,
#   'name': 'Bani Yas City',
#   'latitude': 24.30978,
#   'longitude': 54.62944,
#   'countrycode': 'AE',
#   'population': 80498,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Bani Yas',
#    'Bani Yas City',
#    'mdynt bny yas',
#    'مدينة بني ياس']},
#  '12042053': {'geonameid': 12042053,
#   'name': 'Musaffah',
#   'latitude': 24.35893,
#   'longitude': 54.48267,
#   'countrycode': 'AE',
#   'population': 243341,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Musaffa', 'Musaffah City', 'msfh', 'Мусаффа', 'مصفح']},
#  '12047416': {'geonameid': 12047416,
#   'name': 'Al Shamkhah City',
#   'latitude': 24.39268,
#   'longitude': 54.70779,
#   'countrycode': 'AE',
#   'population': 61710,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Al Shamkhah City', 'mdynt alshamkht', 'مدينة الشامخة']},
#  '12047417': {'geonameid': 12047417,
#   'name': 'Reef Al Fujairah City',
#   'latitude': 25.14479,
#   'longitude': 56.24764,
#   'countrycode': 'AE',
#   'population': 82310,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '04',
#   'alternatenames': ['Reef Al Fujairah City', 'ryf alfjyrt', 'ريف الفجيرة']},
#  '13118420': {'geonameid': 13118420,
#   'name': "Al Bada'a",
#   'latitude': 25.22462,
#   'longitude': 55.26888,
#   'countrycode': 'AE',
#   'population': 18816,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['albdʿ', 'البدع']},
#  '13118421': {'geonameid': 13118421,
#   'name': 'Al Muteena',
#   'latitude': 25.27375,
#   'longitude': 55.32265,
#   'countrycode': 'AE',
#   'population': 48739,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Muteena']},
#  '13118422': {'geonameid': 13118422,
#   'name': 'Al Mizhar First',
#   'latitude': 25.24805,
#   'longitude': 55.44128,
#   'countrycode': 'AE',
#   'population': 17498,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Mizhar 1']},
#  '13118424': {'geonameid': 13118424,
#   'name': 'Dubai Silicon Oasis',
#   'latitude': 25.11985,
#   'longitude': 55.38718,
#   'countrycode': 'AE',
#   'population': 90000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Silicon Oasis']},
#  '13118431': {'geonameid': 13118431,
#   'name': 'Al Furjan',
#   'latitude': 25.02651,
#   'longitude': 55.14565,
#   'countrycode': 'AE',
#   'population': 26000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '13118432': {'geonameid': 13118432,
#   'name': 'Business Bay',
#   'latitude': 25.18544,
#   'longitude': 55.26969,
#   'countrycode': 'AE',
#   'population': 191000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['']},
#  '13118433': {'geonameid': 13118433,
#   'name': 'Al Qusais 1',
#   'latitude': 25.27925,
#   'longitude': 55.36995,
#   'countrycode': 'AE',
#   'population': 48378,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Al Qusais First']},
#  '13118437': {'geonameid': 13118437,
#   'name': 'Halwan',
#   'latitude': 25.34586,
#   'longitude': 55.42165,
#   'countrycode': 'AE',
#   'population': 19389,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['']},
#  '13118438': {'geonameid': 13118438,
#   'name': 'Al Sajaah',
#   'latitude': 25.31532,
#   'longitude': 55.63211,
#   'countrycode': 'AE',
#   'population': 53079,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '06',
#   'alternatenames': ['']},
#  '13118439': {'geonameid': 13118439,
#   'name': 'Lahbab',
#   'latitude': 25.03763,
#   'longitude': 55.59135,
#   'countrycode': 'AE',
#   'population': 53079,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '03',
#   'alternatenames': ['Lehbab', 'lhbab', 'لهباب']},
#  '13118447': {'geonameid': 13118447,
#   'name': 'Mohammed Bin Zayed City',
#   'latitude': 24.34794,
#   'longitude': 54.55368,
#   'countrycode': 'AE',
#   'population': 85000,
#   'timezone': 'Asia/Dubai',
#   'admin1code': '01',
#   'alternatenames': ['Mohammed Bin Zayed']},
#  '1120985': {'geonameid': 1120985,
#   'name': 'Zaranj',
#   'latitude': 30.95962,
#   'longitude': 61.86037,
#   'countrycode': 'AF',
#   'population': 49851,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '19',
#   'alternatenames': ['Sarandsch',
#    'ZAJ',
#    'Zaranas',
#    'Zarandj',
#    'Zarandz',
#    'Zarandzas',
#    'Zarandzh',
#    'Zarandż',
#    'Zarandžas',
#    'Zarang',
#    'Zarani',
#    'Zaranj',
#    'Zaranĝ',
#    'Zerenc',
#    'Zhazang',
#    'Zərənc',
#    'zaranja',
#    'zha lan ji',
#    'zrnj',
#    'Зарандж',
#    'Зарани',
#    'Заранҷ',
#    'زرنج',
#    'ज़रंज',
#    '扎兰季']},
#  '1121381': {'geonameid': 1121381,
#   'name': 'Bāzār-e Yakāwlang',
#   'latitude': 34.73525,
#   'longitude': 66.97379,
#   'countrycode': 'AF',
#   'population': 65000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '05',
#   'alternatenames': ['Bazar-e Yakavlang',
#    'Bazar-e Yakawlang',
#    'Bazar-e Yekawlang',
#    'Bazare Yakawlang',
#    'Bazari-Yakavlang',
#    'Bāzār-e Yakāvlang',
#    'Bāzār-e Yakāwlang',
#    'Bāzār-e Yekāwlang',
#    'Bāzāṟe Yakāwlang',
#    'Yakaulang',
#    'Yakavlang',
#    'Yakawlang',
#    'Yakāvlang',
#    'Yakāwlang',
#    'bazar ykawlng',
#    'بازار يکاولنگ']},
#  '1123004': {'geonameid': 1123004,
#   'name': 'Taloqan',
#   'latitude': 36.73605,
#   'longitude': 69.53451,
#   'countrycode': 'AF',
#   'population': 64256,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '26',
#   'alternatenames': ['Khanabad',
#    'TQN',
#    'Taikhan',
#    'Taleqan',
#    'Talikan',
#    'Talikhan',
#    'Taliqan',
#    'Talkan',
#    'Talokan',
#    'Taloqan',
#    'Talugan',
#    'Talukan',
#    'Talukanas',
#    'Taluqan',
#    'Tologan',
#    'Tâloqân',
#    'Tāleqān',
#    'Tāloqān',
#    'Tāluqān',
#    'Tālīqān',
#    'ta lu kan',
#    'talokam',
#    'talokuvan',
#    'taloqana',
#    'talqan',
#    'Таликан',
#    'Талукан',
#    'تالقان',
#    'तालोक़ान',
#    'तालोकां',
#    'தலோகுவான்',
#    'თალიკანი',
#    '塔卢坎']},
#  '1125155': {'geonameid': 1125155,
#   'name': 'Shīnḏanḏ',
#   'latitude': 33.30294,
#   'longitude': 62.1474,
#   'countrycode': 'AF',
#   'population': 29264,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Asfazar',
#    'Asfazār',
#    'OAH',
#    'Sabzavar',
#    'Sabzavār',
#    'Sabzawar',
#    'Sabzevar',
#    'Sabzevār',
#    'Shindand',
#    'Shīndand',
#    'Shīnḏanḏ',
#    'Sindand',
#    'shyndnd',
#    'Šīndand',
#    'Шинданд',
#    'شيندند',
#    'شیندند',
#    'شینډنډ']},
#  '1125444': {'geonameid': 1125444,
#   'name': 'Shibirghān',
#   'latitude': 36.66757,
#   'longitude': 65.7529,
#   'countrycode': 'AF',
#   'population': 55641,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '31',
#   'alternatenames': ['Markaz-e Wilayat-e Shibirghan',
#    'Markaz-e Wilāyat-e Shibirghan',
#    'Seberghan',
#    'Sebeṟghān',
#    'Shahr-e Sheberghan',
#    'Shahr-e Sheberghān',
#    'Shayurgan',
#    'Shebergan',
#    'Sheberghan',
#    'Sheberghān',
#    'Sheberkhan',
#    'Shefrogan',
#    'Shibarghan',
#    'Shibarghān',
#    'Shibergan',
#    'Shibirghan',
#    'Shibirghān',
#    'mrkz wlayt shbrghan',
#    'shbrghan',
#    'shbrghn',
#    'Шеберган',
#    'شبرغان',
#    'شبرغن',
#    'مرکز ولايت شبرغان']},
#  '1125896': {'geonameid': 1125896,
#   'name': 'Shahrak',
#   'latitude': 34.10737,
#   'longitude': 64.3052,
#   'countrycode': 'AF',
#   'population': 15967,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '09',
#   'alternatenames': ['Bati Dara',
#    'Kala Shaharak',
#    'Kala Shahrak',
#    'Kala Shahārak',
#    'Markaz-e Shahrak',
#    'Qal`eh Shaharak',
#    'Qal`eh-ye Bati Darrah',
#    'Qala Bati Dara',
#    'Qala Batī Dara',
#    'Qala Shaharak',
#    'Qala Shahārak',
#    'Qala Sharak',
#    'Qal‘eh Shahārak',
#    'Qal‘eh-ye Bati Darrah',
#    'Sahrak',
#    'Shahrag',
#    'Shahrak',
#    'Shakhrak',
#    'Sharak',
#    'Shāhrag',
#    'Shāhrak',
#    'Wala Shahrak',
#    'shhrk',
#    'Šahrak',
#    'شهرک']},
#  '1127110': {'geonameid': 1127110,
#   'name': 'Sar-e Pul',
#   'latitude': 36.21544,
#   'longitude': 65.93249,
#   'countrycode': 'AF',
#   'population': 52121,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '33',
#   'alternatenames': ['Sar-e Pol',
#    'Sar-e Pul',
#    'Sar-i-Pul',
#    "Sari-Pul'",
#    'sr pl',
#    'Сари-Пуль',
#    'سر پل']},
#  '1127628': {'geonameid': 1127628,
#   'name': 'Sang-e Chārak',
#   'latitude': 35.84972,
#   'longitude': 66.43694,
#   'countrycode': 'AF',
#   'population': 15377,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '33',
#   'alternatenames': ['Sang-e Charak', 'Sang-e Chārak']},
#  '1127768': {'geonameid': 1127768,
#   'name': 'Aībak',
#   'latitude': 36.26468,
#   'longitude': 68.01551,
#   'countrycode': 'AF',
#   'population': 47823,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '32',
#   'alternatenames': ['Aibak',
#    'Aybak',
#    'Aībak',
#    'Eybak',
#    'Haibak',
#    'Samagan',
#    'Samangan',
#    'Samangān',
#    'aybk',
#    'smngan',
#    'Āybak',
#    'Саманган',
#    'آیبک',
#    'ایبک',
#    'سمنگان']},
#  '1128265': {'geonameid': 1128265,
#   'name': 'Rustāq',
#   'latitude': 37.12604,
#   'longitude': 69.83045,
#   'countrycode': 'AF',
#   'population': 25636,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '26',
#   'alternatenames': ['Rostaq',
#    'Rostāq',
#    'Rustak',
#    'Rustaq',
#    'Rustāq',
#    'rstaq',
#    'رستاق',
#    'Ṟustāq']},
#  '1129516': {'geonameid': 1129516,
#   'name': 'Qarqīn',
#   'latitude': 37.41853,
#   'longitude': 66.04358,
#   'countrycode': 'AF',
#   'population': 15018,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '31',
#   'alternatenames': ['Karkin',
#    'Karkin Bazar',
#    'Kkhanika',
#    'Qarkin',
#    'Qarqin',
#    'Qarqīn',
#    'Quarkin',
#    'qrqyn',
#    'Кханика',
#    'قرقین']},
#  '1129648': {'geonameid': 1129648,
#   'name': 'Qarāwul',
#   'latitude': 37.21959,
#   'longitude': 68.7802,
#   'countrycode': 'AF',
#   'population': 24544,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '24',
#   'alternatenames': ['Hazrat Imam',
#    'Hazrat Imam Saiyid',
#    'Hazrat Imām',
#    'Karaul',
#    'Qaravol',
#    'Qarawul',
#    'Qarāvol',
#    'Qarāwul',
#    'Qaṟāwul',
#    'qrawl',
#    'قراول']},
#  '1130490': {'geonameid': 1130490,
#   'name': 'Pul-e Khumrī',
#   'latitude': 35.94458,
#   'longitude': 68.71512,
#   'countrycode': 'AF',
#   'population': 56369,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '03',
#   'alternatenames': ['Pol-e Khomri',
#    'Pol-e Khomrī',
#    'Pul-e Khumri',
#    'Pul-e Khumrī',
#    'Pul-i-Khomri',
#    'Pul-i-Khumri',
#    'Pule Khumri',
#    'Pule Khumṟi',
#    'Puli-Khumri',
#    'pl khmry',
#    'Пули-Хумри',
#    'پل خمری']},
#  '1131316': {'geonameid': 1131316,
#   'name': 'Paghmān',
#   'latitude': 34.58787,
#   'longitude': 68.95091,
#   'countrycode': 'AF',
#   'population': 49157,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '13',
#   'alternatenames': ['Paghman',
#    'Paghman Palace',
#    'Paghmān',
#    'Pagman',
#    'pghman',
#    'Пагман',
#    'پغمان']},
#  '1131833': {'geonameid': 1131833,
#   'name': 'Nīlī',
#   'latitude': 33.72178,
#   'longitude': 66.13023,
#   'countrycode': 'AF',
#   'population': 30058,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '41',
#   'alternatenames': ['Nili',
#    'Nīlī',
#    'Qaryah-e Nili',
#    'Qaryah-e Nīlī',
#    'nyly',
#    'نیلی']},
#  '1132495': {'geonameid': 1132495,
#   'name': 'Nahrīn',
#   'latitude': 36.0649,
#   'longitude': 69.13343,
#   'countrycode': 'AF',
#   'population': 22363,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '03',
#   'alternatenames': ['Nahrin',
#    'Nahrīn',
#    'Nakhrin',
#    'Narain',
#    'Narin',
#    'Narīn',
#    'nhryn',
#    'Нахрин',
#    'نهرین']},
#  '1133453': {'geonameid': 1133453,
#   'name': 'Maymana',
#   'latitude': 35.92139,
#   'longitude': 64.78361,
#   'countrycode': 'AF',
#   'population': 75900,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '07',
#   'alternatenames': ['Daerah Maymana',
#    'MMZ',
#    'Maimana',
#    'Maimanah',
#    'Maimāna',
#    'Majmana',
#    'Maymana',
#    'Maymanah',
#    'Maïmana',
#    'Maīmanah',
#    'Meimana',
#    'Mejmene',
#    'Meymaneh',
#    'Meymene',
#    'Mimana',
#    'Quan Maymana',
#    'Quận Maymana',
#    'mai ma na',
#    'meyamana',
#    'mymnh',
#    'Меймене',
#    'ضلع میمنہ',
#    'ميمنه ولسوالۍ',
#    'میمنه',
#    'میمنہ',
#    'मेयमना',
#    '迈马纳']},
#  '1133574': {'geonameid': 1133574,
#   'name': 'Mehtar Lām',
#   'latitude': 34.67139,
#   'longitude': 70.20944,
#   'countrycode': 'AF',
#   'population': 17345,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '35',
#   'alternatenames': ['Laghman',
#    'Mehtar Lam',
#    'Mehtar Lām',
#    'Mekhtarlam',
#    'Metarlam',
#    'Mir Talam Saheb Ziarat',
#    'Mitarlam',
#    'Miterlam',
#    'Mīr Talām Şāḩeb Zīārat',
#    'Nawar Lam',
#    'Nāwar Lam',
#    'mhtr lam',
#    'Митарлам',
#    'مهتر لام']},
#  '1133616': {'geonameid': 1133616,
#   'name': 'Mazār-e Sharīf',
#   'latitude': 36.70904,
#   'longitude': 67.11087,
#   'countrycode': 'AF',
#   'population': 523300,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '30',
#   'alternatenames': ['MZR',
#    'Masar-e Scharif',
#    'Mazar-e Sarif',
#    'Mazar-e Sharif',
#    'Mazar-e Šarif',
#    'Mazar-e-Sharif',
#    'Mazar-i Szarif',
#    'Mazar-i-Sharif',
#    'Mazare Srif',
#    'Mazari Sharif',
#    'Mazari-Sharif',
#    'Mazār-e Sharīf',
#    'Mazār-e Šarīf',
#    'Mazār-i-Sharīf',
#    'Mazāre S̄rīf',
#    'majaleu-isyalipeu',
#    'mazarisharifu',
#    'mzar shryf',
#    'Мазари-Шариф',
#    'مزار شريف',
#    'مزار شریف',
#    'マザーリシャリーフ',
#    '마자르이샤리프']},
#  '1134720': {'geonameid': 1134720,
#   'name': 'Lashkar Gāh',
#   'latitude': 31.59382,
#   'longitude': 64.37161,
#   'countrycode': 'AF',
#   'population': 43934,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '10',
#   'alternatenames': ['BST',
#    'Bist',
#    'Bost',
#    'Bust',
#    'Lashkar Gah',
#    'Lashkar Gāh',
#    'Lashkargah Bust',
#    'Lashkargakh',
#    'Laskargah',
#    'Las̲h̲kargāh Busṯ',
#    'Laškargāh',
#    'Nawab City',
#    'lshkr gah',
#    'Лашкаргах',
#    'لشكر گاه',
#    'لښکرگاه بسټ']},
#  '1135158': {'geonameid': 1135158,
#   'name': 'Kushk',
#   'latitude': 33.29565,
#   'longitude': 61.95221,
#   'countrycode': 'AF',
#   'population': 16952,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Kushk',
#    'Kusk',
#    'Kus̄k',
#    'Kūshk',
#    'kshk',
#    'Кушк',
#    'کشک']},
#  '1135689': {'geonameid': 1135689,
#   'name': 'Kunduz',
#   'latitude': 36.72895,
#   'longitude': 68.857,
#   'countrycode': 'AF',
#   'population': 161902,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '24',
#   'alternatenames': ['Kondoz',
#    'Konduz',
#    'Kondôz',
#    'Kondūz',
#    'Kundus',
#    'Kunduz',
#    'Kunduz khot',
#    'Kunduzas',
#    'Kundúz',
#    'Kundūz',
#    'Kundūzas',
#    'Qonduz',
#    'Qondūz',
#    'Qunduz',
#    'Qundūz',
#    'Qunḏūz',
#    'Shahr-e Qondoz',
#    'UND',
#    'kantacu',
#    'kndwz',
#    'kndz',
#    'kuduza',
#    'kun dou shi',
#    'kundouzu',
#    'kunduja',
#    'kundujeu',
#    'kundus',
#    'kunduza',
#    'qndwz',
#    'qndz',
#    'Кундуз',
#    'Кундуз хот',
#    'قندز',
#    'قندوز',
#    'كندز',
#    'کندوز',
#    'कुंदुज़',
#    'কুন্দুজ',
#    'ਕੁੰਦੂਜ਼',
#    'கண்டசு',
#    'കുന്ദൂസ്',
#    'ყუნდუზი',
#    'クンドゥーズ',
#    '昆都士',
#    '쿤두즈']},
#  '1136469': {'geonameid': 1136469,
#   'name': 'Khōst',
#   'latitude': 33.33951,
#   'longitude': 69.92041,
#   'countrycode': 'AF',
#   'population': 96123,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '37',
#   'alternatenames': ['KHT',
#    'Khost',
#    'Khowst',
#    'Khōst',
#    'Matun',
#    'Matūn',
#    'khwst',
#    'mtwn',
#    'Хост',
#    'خوست',
#    'متون']},
#  '1136575': {'geonameid': 1136575,
#   'name': 'Khulm',
#   'latitude': 36.69736,
#   'longitude': 67.69826,
#   'countrycode': 'AF',
#   'population': 64933,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '30',
#   'alternatenames': ['Bazar-e Khulm',
#    'Bāzār-e Khulm',
#    'Kholm',
#    'Khulm',
#    'Tashkurgan',
#    'Tashkurghan',
#    'Tashqorghan',
#    'Tashqurghan',
#    'Tāshkurghān',
#    'Tāshqorghān',
#    'Tāshqurghān',
#    'bazar khlm',
#    'khlm',
#    'tashqrghan',
#    'Ташкурган',
#    'بازار خلم',
#    'تاشقرغان',
#    'خلم']},
#  '1136863': {'geonameid': 1136863,
#   'name': 'Khāsh',
#   'latitude': 31.52919,
#   'longitude': 62.79055,
#   'countrycode': 'AF',
#   'population': 15133,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '19',
#   'alternatenames': ['Khas', 'Khash', 'Khāsh', 'Khās̄', 'khash', 'خاش']},
#  '1137079': {'geonameid': 1137079,
#   'name': 'Khān Neshīn',
#   'latitude': 30.5488,
#   'longitude': 63.7888,
#   'countrycode': 'AF',
#   'population': 25600,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '10',
#   'alternatenames': ['Khan Nashim',
#    'Khan Nashin',
#    'Khan Neshin',
#    'Khan Nishin',
#    'Khanashin',
#    'Khaneshin',
#    'Khannesin',
#    'Khān Nashīn',
#    'Khān Neshīn',
#    'Khān Nishīn',
#    'Khāneshīn',
#    'Khānnešīn',
#    'khan nshyn',
#    'خان نشین']},
#  '1137168': {'geonameid': 1137168,
#   'name': 'Khanabad',
#   'latitude': 36.68304,
#   'longitude': 69.11279,
#   'countrycode': 'AF',
#   'population': 71531,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '24',
#   'alternatenames': ['Khan Abad',
#    'Khanabad',
#    'Khān Ābād',
#    'Khānābād',
#    'khan abad',
#    'Ханабад',
#    'خان آباد']},
#  '1137807': {'geonameid': 1137807,
#   'name': 'Karukh',
#   'latitude': 34.48108,
#   'longitude': 62.5863,
#   'countrycode': 'AF',
#   'population': 17484,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Karokh', 'Karrukh', 'Karukh', 'Kaṟukh', 'krkh', 'کرخ']},
#  '1138336': {'geonameid': 1138336,
#   'name': 'Kandahār',
#   'latitude': 31.61332,
#   'longitude': 65.71013,
#   'countrycode': 'AF',
#   'population': 523300,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '23',
#   'alternatenames': ['Candahar',
#    'KDH',
#    'Kandagar',
#    'Kandahar',
#    'Kandaharo',
#    'Kandahār',
#    'Kandehar',
#    'Kandhar',
#    'Qandahar',
#    'Qandahār',
#    'Qanḏahāṟ',
#    'kan da ha',
#    'kandaharu',
#    'kndhar',
#    'qndhar',
#    'qndhʼr',
#    'Кандагар',
#    'קנדהאר',
#    'قندهار',
#    'كندهار',
#    'カンダハール',
#    '坎大哈']},
#  '1138958': {'geonameid': 1138958,
#   'name': 'Kabul',
#   'latitude': 34.52813,
#   'longitude': 69.17233,
#   'countrycode': 'AF',
#   'population': 4434550,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '13',
#   'alternatenames': ['Cabool',
#    'Caboul',
#    'Cabul',
#    'Cabura',
#    'Cabúl',
#    'Caubul',
#    'KBL',
#    'Kabil',
#    'Kaboel',
#    'Kabol',
#    'Kaboul',
#    'Kabul',
#    'Kabula',
#    'Kabulas',
#    'Kabuli',
#    'Kabulo',
#    'Kabura',
#    'Kabúl',
#    'Kabûl',
#    'Kampoul',
#    'Kobul',
#    'Kubha',
#    'Kábul',
#    'Kâbil',
#    'Kābol',
#    'ka bu er',
#    'kabl',
#    'kabul',
#    'kabula',
#    'kabuli',
#    'kaburu',
#    'kabwl',
#    'kapul',
#    'ke bu er',
#    'khabul',
#    'Καμπούλ',
#    'Кабул',
#    'Кобул',
#    'Քաբուլ',
#    'קאבול',
#    'كابل',
#    'كابۇل',
#    'کابل',
#    'کابول',
#    'काबुल',
#    'কাবুল',
#    'ਕਾਬੁਲ',
#    'କାବୁଲ',
#    'காபூல்',
#    'ಕಾಬುಲ್',
#    'കാബൂൾ',
#    'කාබුල්',
#    'คาบูล',
#    'ཁ་པལ།',
#    'ཁ་པུལ།',
#    'ქაბული',
#    'ካቡል',
#    'ទីក្រុងកាបូល',
#    'カブール',
#    'カーブル',
#    '喀布尔',
#    '喀布爾',
#    '카불']},
#  '1139715': {'geonameid': 1139715,
#   'name': 'Jalālābād',
#   'latitude': 34.42647,
#   'longitude': 70.45153,
#   'countrycode': 'AF',
#   'population': 271900,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '18',
#   'alternatenames': ['Djelalabad',
#    'Dschalalabad',
#    'Dzalalabad',
#    'Dzhelalabad',
#    'Dżalalabad',
#    'JAA',
#    'Jalakot',
#    'Jalal-Kut',
#    'Jalalabad',
#    'Jalalkoat',
#    'Jalalkot',
#    'Jalālkot',
#    'Jalālābād',
#    'Jelalabad',
#    'Tarun City',
#    'jalalabada',
#    'jlal abad',
#    'Джелалабад',
#    'جلال آباد',
#    'جلال\u200cآباد',
#    'জালালাবাদ']},
#  '1139807': {'geonameid': 1139807,
#   'name': 'Jabal os Saraj',
#   'latitude': 35.11833,
#   'longitude': 69.23778,
#   'countrycode': 'AF',
#   'population': 15032,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '40',
#   'alternatenames': ['Djabal-ul-Seradj',
#    "Dzhabal'-Ussaradzh",
#    'Dzhabal’-Ussaradzh',
#    'Jabal Saraj',
#    'Jabal os Saraj',
#    'Jabal os Sarāj',
#    'Jabal us Siraj',
#    'Jabal us Sirāj',
#    'Jabal-us-Sirai',
#    'Jabalussaraj',
#    'Jabalussaṟāj',
#    'Jabl-us-Seraj',
#    'Jabl-us-Siraj',
#    'Jabul Saraj',
#    'Jibal-as-Seraj',
#    'Parwan',
#    'jbl alsraj',
#    'جبل السراج']},
#  '1140026': {'geonameid': 1140026,
#   'name': 'Herāt',
#   'latitude': 34.34817,
#   'longitude': 62.19967,
#   'countrycode': 'AF',
#   'population': 574300,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Gerat',
#    'HEA',
#    'Herat',
#    'Herāt',
#    'Hérat',
#    'Kherat',
#    'Shahr-e Herat',
#    'Shahr-e Herāt',
#    'he la te',
#    'herato',
#    'hrat',
#    'Герат',
#    'Херат',
#    'هراة',
#    'هرات',
#    'ヘラート',
#    '赫拉特']},
#  '1141089': {'geonameid': 1141089,
#   'name': 'Ghormach',
#   'latitude': 35.73062,
#   'longitude': 63.78264,
#   'countrycode': 'AF',
#   'population': 30000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '02',
#   'alternatenames': ['Garmak',
#    'Ghormac',
#    'Ghormach',
#    'Ghormāch',
#    'Ghowrmach',
#    'Ghowrmāch',
#    'Ghōrmāc',
#    'Ghōrmāch',
#    'ghwrmach',
#    'ghwrmch',
#    'غورماچ',
#    'غورمچ']},
#  '1141269': {'geonameid': 1141269,
#   'name': 'Ghazni',
#   'latitude': 33.55391,
#   'longitude': 68.42096,
#   'countrycode': 'AF',
#   'population': 141000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '08',
#   'alternatenames': ['GZI',
#    'Gazni',
#    'Ghazni',
#    'Ghaznī',
#    'Shahr-e Ghazni',
#    'Shahr-e Ghaznī',
#    'gazni',
#    'gazuni',
#    'ghznt',
#    'ghzny',
#    'ghznyn',
#    'Газни',
#    'غزنة',
#    'غزنی',
#    'غزنین',
#    'ガズニー']},
#  '1141540': {'geonameid': 1141540,
#   'name': 'Gereshk',
#   'latitude': 31.82089,
#   'longitude': 64.57005,
#   'countrycode': 'AF',
#   'population': 43588,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '10',
#   'alternatenames': ['Gereshk',
#    'Geresk',
#    'Gerešk',
#    'Girishk',
#    'Nahr-e Saraj',
#    'Nahr-e Sarāj',
#    'grshk',
#    'Герешк',
#    'گرشک']},
#  '1141857': {'geonameid': 1141857,
#   'name': 'Gardez',
#   'latitude': 33.59744,
#   'longitude': 69.22592,
#   'countrycode': 'AF',
#   'population': 103601,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '36',
#   'alternatenames': ['GRG',
#    'Gardeyz',
#    'Gardez',
#    'Gardiz',
#    'Gardêz',
#    'Gardēz',
#    'Gardīz',
#    'Gaṟḏēz',
#    'grdyz',
#    'Гардез',
#    'گرديز']},
#  '1142170': {'geonameid': 1142170,
#   'name': 'Fayzabad',
#   'latitude': 37.11664,
#   'longitude': 70.58002,
#   'countrycode': 'AF',
#   'population': 44421,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '01',
#   'alternatenames': ['FBD',
#    'Faizabad',
#    'Faizābād',
#    'Fajzabad',
#    'Faydz Abad',
#    'Fayzabad',
#    'Fayḏẕ Ābāḏ',
#    'Fazelabad',
#    'Faīẕābād',
#    'Feyzabad',
#    'Feyẕābād',
#    'fyd abad',
#    'Файзабад',
#    'فیض آباد']},
#  '1142264': {'geonameid': 1142264,
#   'name': 'Farah',
#   'latitude': 32.37451,
#   'longitude': 62.11638,
#   'countrycode': 'AF',
#   'population': 43561,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '06',
#   'alternatenames': ['FAH',
#    'Farah',
#    'Farahas',
#    'Farakh',
#    'Farâh',
#    'Farāh',
#    'Ferah',
#    'fa la',
#    'faraha',
#    'frah',
#    'pala',
#    'para',
#    'Фарах',
#    'فراه',
#    'فراہ',
#    'फ़राह',
#    'பாரா',
#    '法拉',
#    '파라']},
#  '1142404': {'geonameid': 1142404,
#   'name': 'Eslam Qaleh',
#   'latitude': 34.66667,
#   'longitude': 61.06667,
#   'countrycode': 'AF',
#   'population': 18086,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '11',
#   'alternatenames': ['Eslam Qal`eh',
#    'Eslamqal`a',
#    'Eslamqal‘a',
#    'Eslām Qal‘eh',
#    'Islam Kala',
#    'Islam Killa',
#    'Islam Qal`ah',
#    'Islam Qala',
#    'Islām Kala',
#    'Islām Qala',
#    'Islām Qal‘ah',
#    'Kafar Qal`eh',
#    'Kafir Kala',
#    'Kafir Qala',
#    'Kāfar Qal‘eh']},
#  '1145352': {'geonameid': 1145352,
#   'name': 'Charikar',
#   'latitude': 35.01361,
#   'longitude': 69.17139,
#   'countrycode': 'AF',
#   'population': 53676,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '40',
#   'alternatenames': ['Caharikar',
#    'Carikar',
#    'Carikaras',
#    'Chaharikar',
#    'Chahārīkār',
#    'Chairkar',
#    'Charekar',
#    'Charikar',
#    'Chāirkār',
#    'Chārīkār',
#    'Czarikar',
#    'Cāṟikāṟ',
#    'Tscharikar',
#    'carikar',
#    'carikara',
#    'charikari',
#    'charykar',
#    'qia li ka er',
#    'Çarikar',
#    'Ĉarikar',
#    'Čahārikār',
#    'Čarikaras',
#    'Чарикар',
#    'چاريكار',
#    'چاریکار',
#    'चारीकार',
#    'চরিকর',
#    'சாரிகார்',
#    'ჩარიქარი',
#    '恰里卡尔']},
#  '1147066': {'geonameid': 1147066,
#   'name': 'Baraki Barak',
#   'latitude': 33.96744,
#   'longitude': 68.9492,
#   'countrycode': 'AF',
#   'population': 22305,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '17',
#   'alternatenames': ['Barah Ki Barak',
#    'Barah Kī Barak',
#    'Baraki Barak',
#    'Baraki Burak',
#    'Barakibarak',
#    'Barakī Barak',
#    'Barqi Barq',
#    'OAA',
#    'brh ky brk',
#    'brky brk',
#    'بره کی برک',
#    'برکی برک']},
#  '1147242': {'geonameid': 1147242,
#   'name': 'Bāmyān',
#   'latitude': 34.82156,
#   'longitude': 67.82734,
#   'countrycode': 'AF',
#   'population': 61863,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '05',
#   'alternatenames': ['BIN',
#    'Bamian',
#    'Bamiyan',
#    'Bamyan',
#    'Bāmyān',
#    'Bāmīān',
#    'Kala Sarkari',
#    'Qal`a Sarkarit',
#    'Qala Sarkari',
#    'Qala Sarkāri',
#    'Qal‘a Sarkārit',
#    'bamyan',
#    'باميان']},
#  '1147290': {'geonameid': 1147290,
#   'name': 'Balkh',
#   'latitude': 36.75635,
#   'longitude': 66.8972,
#   'countrycode': 'AF',
#   'population': 114883,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '30',
#   'alternatenames': ['Bactra',
#    'Bactresh',
#    'Bakhtar',
#    'Balch',
#    'Balchas',
#    'Balh',
#    'Balhika',
#    'Balho',
#    'Balj',
#    'Balkh',
#    'Balx',
#    'Balĥo',
#    'Bamik',
#    'Bazirabad',
#    'Belh',
#    'Belx',
#    'Bkahdi',
#    'Bākhtar',
#    'Daerah Balkh',
#    'Quan Balkh',
#    'Quận Balkh',
#    'Vazirabad',
#    'ba er he',
#    'balheu',
#    'barufu',
#    'blk',
#    'blkh',
#    'Μπαλχ',
#    'Балх',
#    'Вазирабад',
#    'Բալխ',
#    'בלך',
#    'بلخ',
#    'বাল্\u200cখ',
#    'ബൽഖ്',
#    'バルフ',
#    '巴尔赫',
#    '발흐']},
#  '1147540': {'geonameid': 1147540,
#   'name': 'Baghlān',
#   'latitude': 36.13068,
#   'longitude': 68.70829,
#   'countrycode': 'AF',
#   'population': 108449,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '03',
#   'alternatenames': ['Baghlan',
#    'Baghlan - bghlan',
#    'Baghlan-e Jadid',
#    'Baghlin',
#    'Baghlān',
#    'Baghlān-e Jadīd',
#    'Baglan',
#    'Bagolaggo',
#    'Sana `Ati',
#    'Sana`ati',
#    'bghlan',
#    'bghlan jdyd',
#    'Şanā ‘Ati',
#    'Şanā‘atī',
#    'Баглан',
#    'بغلان',
#    'بغلان جديد',
#    'صناعتی']},
#  '1148106': {'geonameid': 1148106,
#   'name': 'Ārt Khwājah',
#   'latitude': 37.08571,
#   'longitude': 69.47958,
#   'countrycode': 'AF',
#   'population': 18623,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '26',
#   'alternatenames': ['Art Khvajeh (1)',
#    'Art Khwajah',
#    'At Khvajeh',
#    'At Khwaja',
#    'art khwajh',
#    'Ārt Khwājah',
#    'Āt Khvājeh',
#    'Āt Khwāja',
#    'Āṟt Khvājeh (1)',
#    'آرت خواجه']},
#  '1148205': {'geonameid': 1148205,
#   'name': 'Āsmār',
#   'latitude': 35.03333,
#   'longitude': 71.35809,
#   'countrycode': 'AF',
#   'population': 15708,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '34',
#   'alternatenames': ['Asma',
#    'Asmar',
#    'Asmār',
#    'asmar',
#    'Āsmā',
#    'Āsmār',
#    'آسمار',
#    'اسمار']},
#  '1148311': {'geonameid': 1148311,
#   'name': 'Asadābād',
#   'latitude': 34.87311,
#   'longitude': 71.14697,
#   'countrycode': 'AF',
#   'population': 48400,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '34',
#   'alternatenames': ['Asadabad',
#    'Asadābād',
#    'Assad-Abad',
#    'Caghasaray',
#    'Chagha Serai',
#    'Chagha-Sari',
#    'Chaghah Saray',
#    'Chaghah Sarāy',
#    'Chaghasarai',
#    'Chaghasaray',
#    'Chaghasarāy',
#    'Chagsarai',
#    'Chegheh Saray',
#    'Chegheh Sarāy',
#    'Chigha Sarai',
#    'Chigha Sarāi',
#    'Chigha Serai',
#    'Chigkhasaray',
#    'asd abad',
#    'chghh sray',
#    'Čaghasarāy',
#    'Асадабад',
#    'اسد آباد',
#    'چغه سرای']},
#  '1148658': {'geonameid': 1148658,
#   'name': 'Andkhōy',
#   'latitude': 36.95293,
#   'longitude': 65.12376,
#   'countrycode': 'AF',
#   'population': 29208,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '07',
#   'alternatenames': ['Andkhoi',
#    'Andkhoy',
#    'Andkhui',
#    'Andkhvoy',
#    'Andkhōy',
#    'Andkhōī',
#    'Andkhūi',
#    'Ankhoi',
#    'andkhwy',
#    'اندخوی']},
#  '1429434': {'geonameid': 1429434,
#   'name': 'Bāzārak',
#   'latitude': 35.31292,
#   'longitude': 69.51519,
#   'countrycode': 'AF',
#   'population': 65000,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '42',
#   'alternatenames': ['Bazarak',
#    'Bāzārak',
#    'bazark',
#    'Базарак',
#    'بازارك',
#    'بازارک']},
#  '1469706': {'geonameid': 1469706,
#   'name': 'Markaz-e Woluswalī-ye Āchīn',
#   'latitude': 34.12583,
#   'longitude': 70.70778,
#   'countrycode': 'AF',
#   'population': 15098,
#   'timezone': 'Asia/Kabul',
#   'admin1code': '18',
# ...
#    'silles',
#    'sylht',
#    'sylt',
#    'xi er he te shi',
#    'Силхет',
#    'Сілет',
#    'سلہٹ',
#    'سيلهت',
#    'سیلت',
#    'सिलहट',
#    'সিলেট',
#    'சில்ஹெட்',
#    'സിൽഹെറ്റ്',
#    'シレット',
#    '錫爾赫特市',
#    '실렛']},
#  '1185100': {'geonameid': 1185100,
#   'name': 'Dohār',
#   'latitude': 23.59311,
#   'longitude': 90.14251,
#   'countrycode': 'BD',
#   'population': 45543,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Dohai',
#    'Dohar',
#    'Dohāi',
#    'Dohār',
#    'Sutarpara',
#    'Sutārpara']},
#  '1185105': {'geonameid': 1185105,
#   'name': 'Sunāmganj',
#   'latitude': 25.06889,
#   'longitude': 91.40243,
#   'countrycode': 'BD',
#   'population': 74570,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '86',
#   'alternatenames': ['Sonamganj', 'Sunamganj', 'Sunāmganj']},
#  '1185106': {'geonameid': 1185106,
#   'name': 'Jamālpur',
#   'latitude': 24.91965,
#   'longitude': 89.94812,
#   'countrycode': 'BD',
#   'population': 167900,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Jamaipur',
#    'Jamalpur',
#    'Jamālpur',
#    'Singhjani',
#    'Singhjāni']},
#  '1185107': {'geonameid': 1185107,
#   'name': 'Shibganj',
#   'latitude': 25.00146,
#   'longitude': 89.32266,
#   'countrycode': 'BD',
#   'population': 378701,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Shibgandzh', 'Shibganj', 'Sibganj', 'Шибгандж']},
#  '1185108': {'geonameid': 1185108,
#   'name': 'Shibganj',
#   'latitude': 24.68501,
#   'longitude': 88.15638,
#   'countrycode': 'BD',
#   'population': 35961,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Shibganj', 'Sibganj']},
#  '1185111': {'geonameid': 1185111,
#   'name': 'Sātkhira',
#   'latitude': 22.70817,
#   'longitude': 89.07185,
#   'countrycode': 'BD',
#   'population': 128918,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Satkhira', 'Shatkhira', 'Sātkhira']},
#  '1185115': {'geonameid': 1185115,
#   'name': 'Sirajganj',
#   'latitude': 24.45771,
#   'longitude': 89.70802,
#   'countrycode': 'BD',
#   'population': 127481,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['SAJ',
#    'Serajganj Municipality',
#    'Siradzhgandzh',
#    'Sirajganj',
#    'Siranganj',
#    'Sirājganj',
#    'sirajaganja',
#    'Сираджгандж',
#    'সিরাজগঞ্জ']},
#  '1185116': {'geonameid': 1185116,
#   'name': 'Netrakona',
#   'latitude': 24.88352,
#   'longitude': 90.72898,
#   'countrycode': 'BD',
#   'population': 79016,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Netrakona', 'Satpai', 'Sātpāi']},
#  '1185117': {'geonameid': 1185117,
#   'name': 'Narsingdi',
#   'latitude': 23.92298,
#   'longitude': 90.71768,
#   'countrycode': 'BD',
#   'population': 281080,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Narsingdi', 'Narsinghdi', 'Satirpara', 'Satirpāra']},
#  '1185120': {'geonameid': 1185120,
#   'name': 'Sandwīp',
#   'latitude': 22.51409,
#   'longitude': 91.45491,
#   'countrycode': 'BD',
#   'population': 52152,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Sandvip', 'Sandwip', 'Sandwīp', 'Сандвип']},
#  '1185121': {'geonameid': 1185121,
#   'name': 'Shāhzādpur',
#   'latitude': 24.17687,
#   'longitude': 89.5988,
#   'countrycode': 'BD',
#   'population': 102420,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Sahzadpur', 'Shahzadpur', 'Shāhzādpur']},
#  '1185127': {'geonameid': 1185127,
#   'name': 'Rāmganj',
#   'latitude': 23.1006,
#   'longitude': 90.84989,
#   'countrycode': 'BD',
#   'population': 55241,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Ramganj', 'Ratanpur', 'Rāmganj']},
#  '1185128': {'geonameid': 1185128,
#   'name': 'Rajshahi',
#   'latitude': 24.374,
#   'longitude': 88.60114,
#   'countrycode': 'BD',
#   'population': 763580,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['RJH',
#    'Radzhshakhi',
#    'Rajshahi',
#    'Rampur Baolia',
#    'Rampur Bauleah',
#    'Rampur Boalia',
#    'Rājshāhi',
#    'rajasahi',
#    'Раджшахи',
#    'রাজশাহী']},
#  '1185138': {'geonameid': 1185138,
#   'name': 'Pirojpur',
#   'latitude': 22.57965,
#   'longitude': 89.97521,
#   'countrycode': 'BD',
#   'population': 54418,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Perijpur', 'Perojpur Municipality', 'Pirojpur']},
#  '1185141': {'geonameid': 1185141,
#   'name': 'Panchagarh',
#   'latitude': 26.33338,
#   'longitude': 88.55777,
#   'countrycode': 'BD',
#   'population': 48531,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Pachagar', 'Pachagarh', 'Pachāgarh', 'Panchagarh']},
#  '1185148': {'geonameid': 1185148,
#   'name': 'Patiya',
#   'latitude': 22.29543,
#   'longitude': 91.979,
#   'countrycode': 'BD',
#   'population': 51360,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Patia', 'Patiya']},
#  '1185149': {'geonameid': 1185149,
#   'name': 'Parbatipur',
#   'latitude': 25.66369,
#   'longitude': 88.93093,
#   'countrycode': 'BD',
#   'population': 48020,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Parbatipur', 'Parvatipur', 'Pārvatīpur']},
#  '1185155': {'geonameid': 1185155,
#   'name': 'Nārāyanganj',
#   'latitude': 23.61352,
#   'longitude': 90.50298,
#   'countrycode': 'BD',
#   'population': 223622,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Narajanganj', 'Narayanganj', 'Nārāyanganj']},
#  '1185156': {'geonameid': 1185156,
#   'name': 'Nālchiti',
#   'latitude': 22.63696,
#   'longitude': 90.27195,
#   'countrycode': 'BD',
#   'population': 38703,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Nalchhiti', 'Nalchiti', 'Nālchiti']},
#  '1185159': {'geonameid': 1185159,
#   'name': 'Nāgarpur',
#   'latitude': 24.05783,
#   'longitude': 89.87696,
#   'countrycode': 'BD',
#   'population': 238422,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Nagarpur', 'Nagurpoor', 'Nāgarpur']},
#  '1185160': {'geonameid': 1185160,
#   'name': 'Nageswari',
#   'latitude': 25.96817,
#   'longitude': 89.69153,
#   'countrycode': 'BD',
#   'population': 49425,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Nagasewari',
#    'Nageshawari',
#    'Nageshwari',
#    'Nageswari',
#    'Nagheswari',
#    'Nāgeshwari',
#    'Paschim Nageswari']},
#  '1185162': {'geonameid': 1185162,
#   'name': 'Mymensingh',
#   'latitude': 24.75636,
#   'longitude': 90.40646,
#   'countrycode': 'BD',
#   'population': 225126,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Majmensingkh',
#    'Mymensing',
#    'Mymensingh',
#    'Nasirabad',
#    'Nasirābād',
#    'mayamanasinha',
#    'Майменсингх',
#    'ময়মনসিংহ']},
#  '1185164': {'geonameid': 1185164,
#   'name': 'Muktāgācha',
#   'latitude': 24.76484,
#   'longitude': 90.25698,
#   'countrycode': 'BD',
#   'population': 24684,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Muktagacha', 'Muktagachha', 'Muktāgācha']},
#  '1185165': {'geonameid': 1185165,
#   'name': 'Mirzāpur',
#   'latitude': 24.10287,
#   'longitude': 90.09841,
#   'countrycode': 'BD',
#   'population': 41137,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Mirzapur', 'Mirzāpur', 'Mrizapur', 'Мирзапур']},
#  '1185166': {'geonameid': 1185166,
#   'name': 'Maulavi Bāzār',
#   'latitude': 24.48888,
#   'longitude': 91.77075,
#   'countrycode': 'BD',
#   'population': 57441,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '86',
#   'alternatenames': ['Maulavi Bazar',
#    'Maulavi Bāzār',
#    'Maulvi Bazar',
#    'Maulvi Bāzār',
#    'Moulvi Bazar',
#    'Moulvi Bazar Municipality',
#    'Moulvi Bāzār',
#    'Moulvibazar']},
#  '1185167': {'geonameid': 1185167,
#   'name': 'Morrelgonj',
#   'latitude': 22.45566,
#   'longitude': 89.85584,
#   'countrycode': 'BD',
#   'population': 31647,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Fakirertakia',
#    'Fakirertākia',
#    'Morrelganj',
#    'Morrelgonj',
#    'Morrellganj']},
#  '1185171': {'geonameid': 1185171,
#   'name': 'Mehendiganj',
#   'latitude': 22.82257,
#   'longitude': 90.52859,
#   'countrycode': 'BD',
#   'population': 39424,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Mehdigunj', 'Mehendiganj', 'mhndyganj', 'مهندیگانج']},
#  '1185173': {'geonameid': 1185173,
#   'name': 'Mathba',
#   'latitude': 22.28616,
#   'longitude': 89.95883,
#   'countrycode': 'BD',
#   'population': 29760,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Matbari',
#    'Matbaria',
#    'Matbāri',
#    'Mathba',
#    'Mathbari',
#    'Mathbaria',
#    'Sankibhanga']},
#  '1185181': {'geonameid': 1185181,
#   'name': 'Lalmonirhat',
#   'latitude': 25.91719,
#   'longitude': 89.44595,
#   'countrycode': 'BD',
#   'population': 65127,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['LLJ',
#    'Lalmanir Hat',
#    'Lalmanirat',
#    'Lalmanirhat',
#    'Lalmonirhat',
#    'Lālmanir Hāt']},
#  '1185183': {'geonameid': 1185183,
#   'name': 'Lākshām',
#   'latitude': 23.24018,
#   'longitude': 91.12143,
#   'countrycode': 'BD',
#   'population': 82290,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Laksam', 'Laksham', 'Lākshām']},
#  '1185186': {'geonameid': 1185186,
#   'name': 'Comilla',
#   'latitude': 23.46186,
#   'longitude': 91.18503,
#   'countrycode': 'BD',
#   'population': 1030000,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['CLA',
#    'Comilla',
#    'Komila',
#    'Komilla',
#    'Komille',
#    'Kumilla',
#    'Kumillā',
#    'khu mi l la',
#    'komilla',
#    'kumilla',
#    'kumirra',
#    'kwmyla',
#    'Комилла',
#    'Комилле',
#    'کومیلا',
#    'कोमिल्ला',
#    'কুমিল্লা',
#    'คูมิลลา',
#    'クミッラ']},
#  '1185188': {'geonameid': 1185188,
#   'name': 'Rangpur',
#   'latitude': 25.74664,
#   'longitude': 89.25166,
#   'countrycode': 'BD',
#   'population': 1031388,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Kotwali',
#    'Kotwāli',
#    'Mosque Rangpur',
#    'RAU',
#    'Rangpur',
#    'Rangpur City',
#    'Rangpuras',
#    'Rongpur',
#    'lang bu er shi',
#    'langpuleu',
#    'rampura',
#    'ranpuru',
#    'Рангпур',
#    'رنگپور شہر',
#    'রংপুর',
#    'ランプル',
#    '朗布尔市',
#    '랑푸르']},
#  '1185191': {'geonameid': 1185191,
#   'name': 'Kushtia',
#   'latitude': 23.9028,
#   'longitude': 89.11943,
#   'countrycode': 'BD',
#   'population': 135724,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Khustia', 'Kushtia']},
#  '1185199': {'geonameid': 1185199,
#   'name': 'Kālīganj',
#   'latitude': 23.40964,
#   'longitude': 89.13801,
#   'countrycode': 'BD',
#   'population': 45631,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Aliganj', 'Kaliganj', 'Kaliganja', 'Kālīganj']},
#  '1185204': {'geonameid': 1185204,
#   'name': 'Jhingergācha',
#   'latitude': 23.11134,
#   'longitude': 89.09061,
#   'countrycode': 'BD',
#   'population': 41957,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Jhikargacha',
#    'Jhikargachha',
#    'Jhikargāchha',
#    'Jhikergacha',
#    'Jhingergacha',
#    'Jhingergācha',
#    'Jhinkargacha']},
#  '1185206': {'geonameid': 1185206,
#   'name': 'Joypur Hāt',
#   'latitude': 25.10147,
#   'longitude': 89.02734,
#   'countrycode': 'BD',
#   'population': 73068,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['Jaipur Hat',
#    'Jaipur Hāt',
#    'Jaypur Hat',
#    'Joypur Hat',
#    'Joypur Hāt',
#    'Joypurhat']},
#  '1185207': {'geonameid': 1185207,
#   'name': 'Ishwardi',
#   'latitude': 24.12858,
#   'longitude': 89.06573,
#   'countrycode': 'BD',
#   'population': 81995,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '83',
#   'alternatenames': ['IRD', 'Ishwardi', 'isbaradi', 'ঈশ্বরদী']},
#  '1185209': {'geonameid': 1185209,
#   'name': 'Habiganj',
#   'latitude': 24.38044,
#   'longitude': 91.41299,
#   'countrycode': 'BD',
#   'population': 88760,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '86',
#   'alternatenames': ['Habiganj',
#    'Habiganj Bazar',
#    'Habiganj Sadar',
#    'Hobiganj',
#    'Khabigandzh',
#    'habiganja',
#    'hby gnj',
#    'hbyganj',
#    'hbyghnj',
#    'hbyjnj',
#    'Хабигандж',
#    'حبيجنج',
#    'حبيغنج',
#    'حبی گنج',
#    'حبیگانج',
#    'হবিগঞ্জ']},
#  '1185210': {'geonameid': 1185210,
#   'name': 'Gaurnadi',
#   'latitude': 22.97372,
#   'longitude': 90.22376,
#   'countrycode': 'BD',
#   'population': 40519,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Gaurnadi', 'Gournadi']},
#  '1185218': {'geonameid': 1185218,
#   'name': 'Gafargaon',
#   'latitude': 24.432,
#   'longitude': 90.5585,
#   'countrycode': 'BD',
#   'population': 34177,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': 'H',
#   'alternatenames': ['Gafargaon', 'Gaffargaon', 'Ghafargaon']},
#  '1185224': {'geonameid': 1185224,
#   'name': 'Feni',
#   'latitude': 23.0144,
#   'longitude': 91.3966,
#   'countrycode': 'BD',
#   'population': 84028,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Feni',
#    'Feni  Bangladesh',
#    'Fenny',
#    'feni',
#    'fyny',
#    'peni',
#    'pheni',
#    'Φένι',
#    'Фени',
#    'فئنی',
#    'فيني',
#    'فینی، بنگلہ دیش',
#    'ফেনী',
#    'பெனி',
#    'フェニ']},
#  '1185236': {'geonameid': 1185236,
#   'name': 'Rāipur',
#   'latitude': 23.0391,
#   'longitude': 90.76808,
#   'countrycode': 'BD',
#   'population': 64652,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Deyanatpur',
#    'Deyānatpur',
#    'Raipur',
#    'Rajpur',
#    'Raypur',
#    'Rāipur',
#    'Райпур']},
#  '1185239': {'geonameid': 1185239,
#   'name': 'Sarankhola',
#   'latitude': 22.31006,
#   'longitude': 89.79113,
#   'countrycode': 'BD',
#   'population': 36470,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '82',
#   'alternatenames': ['Dakshin Rajapur', 'Dakshin Rājāpur', 'Sarankhola']},
#  '1185240': {'geonameid': 1185240,
#   'name': 'Ramna Maidan',
#   'latitude': 23.73333,
#   'longitude': 90.4,
#   'countrycode': 'BD',
#   'population': 143677,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['Dacca Ramna', 'Ramna', 'Ramna Maidan']},
#  '1185241': {'geonameid': 1185241,
#   'name': 'Dhaka',
#   'latitude': 23.7104,
#   'longitude': 90.40744,
#   'countrycode': 'BD',
#   'population': 10356500,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '81',
#   'alternatenames': ['DAC',
#    'Daaka',
#    'Daca',
#    'Dacca',
#    'Daka',
#    'Dakah',
#    'Dakk',
#    'Dakka',
#    'Dakkae',
#    'Dakke',
#    'Dako',
#    'Deka',
#    'Dgaka',
#    'Dhaka',
#    'Dháka',
#    'Dhâkâ',
#    'Dəkkə',
#    'Mujib City',
#    'Ntaka',
#    'Ntakka',
#    'da ka',
#    'daka',
#    'dakka',
#    'dhaka',
#    'dhakka',
#    'dka',
#    'takka',
#    'thaka',
#    'Ντάκα',
#    'Ντάκκα',
#    'Даака',
#    'Дака',
#    'Даккæ',
#    'Дакка',
#    'Дакке',
#    'Дгака',
#    'Դաքքա',
#    'דאקא',
#    'דאקה',
#    'داكا',
#    'داکا',
#    'دكا',
#    'ڈھاکہ',
#    'ޑާކާ',
#    'ढाका',
#    'ঢাকা',
#    'ਢਾਕਾ',
#    'ઢાકા',
#    'ଢାକା',
#    'டாக்கா',
#    'ఢాకా',
#    'ಢಾಕಾ',
#    'ഢാക്ക',
#    'ඩකා',
#    'ธากา',
#    'དྷ་ཁ།',
#    'ဒါကာမြို့',
#    'დაკა',
#    'ዳካ',
#    'ダッカ',
#    '达卡',
#    '達卡',
#    '다카']},
#  '1185247': {'geonameid': 1185247,
#   'name': 'Chilmāri',
#   'latitude': 25.55613,
#   'longitude': 89.67097,
#   'countrycode': 'BD',
#   'population': 49736,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '87',
#   'alternatenames': ['Chillmari', 'Chilmari', 'Chilmāri']},
#  '1185249': {'geonameid': 1185249,
#   'name': 'Chhāgalnāiya',
#   'latitude': 23.02475,
#   'longitude': 91.51091,
#   'countrycode': 'BD',
#   'population': 39335,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Chhagainaya',
#    'Chhagalnaia',
#    'Chhagalnaiya',
#    'Chhagalnaya',
#    'Chhāgalnāiya',
#    'Paschim Chhagalnaiya',
#    'Paschim Chhāgalnāiya',
#    'West Chhagal Naiya',
#    'West Chhagalnaia']},
#  '1185251': {'geonameid': 1185251,
#   'name': 'Lālmohan',
#   'latitude': 22.33774,
#   'longitude': 90.73708,
#   'countrycode': 'BD',
#   'population': 42220,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '85',
#   'alternatenames': ['Char Lalmohan',
#    'Char Lalmohun',
#    'Char Lālmohan',
#    'Dhar Lalmohan',
#    'Lalmohan',
#    'Lālmohan']},
#  '1185252': {'geonameid': 1185252,
#   'name': 'Khagrachhari',
#   'latitude': 23.10787,
#   'longitude': 91.97007,
#   'countrycode': 'BD',
#   'population': 50364,
#   'timezone': 'Asia/Dhaka',
#   'admin1code': '84',
#   'alternatenames': ['Changrachhari',
#    'Khabangpari',
#    'Khagrachari',
#    'Khagrachhari',
#    'Khagrāchari',
#    'Khagrāchhari',
#    'Kkhagrachari',
#    'Кхаграчари']},
#  ...}

# %%
def get_cities_above_population(population_threshold   = 250000):
    result = pd.DataFrame(columns=["geonameid","name","countrycode","latitude","longitude","population"])
    for city_id, city_info in cities.items():
        if city_info['population'] >= population_threshold and city_info['countrycode'] in ALLOWED_COUNTRIES:
            #  get for each records with 1/2 alternate names in order not to miss anything
            alt_names = city_info.get('alternatenames', [])
            result = pd.concat([result, pd.DataFrame([{"geonameid": city_id, "name": city_info['name'], "countrycode": city_info['countrycode'], "latitude": city_info['latitude'], "longitude": city_info['longitude'], "population": city_info['population']}])], ignore_index=True)
            if len(alt_names) > 0:
                result = pd.concat([result, pd.DataFrame([{"geonameid": city_id, "name": alt_names[0], "countrycode": city_info['countrycode'], "latitude": city_info['latitude'], "longitude": city_info['longitude'], "population": city_info['population']}])], ignore_index=True) 
            if len(alt_names) > 1:
                result = pd.concat([result, pd.DataFrame([{"geonameid": city_id, "name": alt_names[1], "countrycode": city_info['countrycode'], "latitude": city_info['latitude'], "longitude": city_info['longitude'], "population": city_info['population']}])], ignore_index=True) 
    return result.sort_values(by="geonameid", ascending=False)

CITIES_300K = get_cities_above_population(300000)
CITIES_250K = get_cities_above_population(250000)
CITIES_200K = get_cities_above_population(200000)
len(CITIES_250K)
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_29436\3213311911.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([result, pd.DataFrame([{"geonameid": city_id, "name": city_info['name'], "countrycode": city_info['countrycode'], "latitude": city_info['latitude'], "longitude": city_info['longitude'], "population": city_info['population']}])], ignore_index=True)
# C:\Users\Adam\AppData\Local\Temp\ipykernel_29436\3213311911.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([result, pd.DataFrame([{"geonameid": city_id, "name": city_info['name'], "countrycode": city_info['countrycode'], "latitude": city_info['latitude'], "longitude": city_info['longitude'], "population": city_info['population']}])], ignore_index=True)
# C:\Users\Adam\AppData\Local\Temp\ipykernel_29436\3213311911.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([result, pd.DataFrame([{"geonameid": city_id, "name": city_info['name'], "countrycode": city_info['countrycode'], "latitude": city_info['latitude'], "longitude": city_info['longitude'], "population": city_info['population']}])], ignore_index=True)
# 480

# %%
CITIES_200K[:50]
# Out:
#     geonameid                             name countrycode  latitude  \
# 174   8354626              Bezirk Hamburg-Nord          DE  53.58935
# 173   8354626  Arrondissement de Hambourg-Nord          DE  53.58935
# 172   8354626                     Hamburg-Nord          DE  53.58935
# 292   8285534                                           ES  40.49840
# 291   8285534              Fuencarral-El Pardo          ES  40.49840
# 10    8063098                                           AT  48.16116
# 9     8063098                        Favoriten          AT  48.16116
# 567    776069                        Białystok          PL  53.13333
# 569    776069                         Balstogė          PL  53.13333
# 568    776069                         Balstoge          PL  53.13333
# 564    769250                           Kielce          PL  50.87033
# 565    769250                           Kel'ce          PL  50.87033
# 566    769250                           Kel'cy          PL  50.87033
# 563    765876                         Lioblens          PL  51.25000
# 562    765876                              LUZ          PL  51.25000
# 561    765876                           Lublin          PL  51.25000
# 558    764484                          Mokotów          PL  52.19340
# 560    764484                         Mokotouf          PL  52.19340
# 559    764484                          Makotau          PL  52.19340
# 557    760778                         Là-tô-mê          PL  51.40253
# 556    760778                         La-to-me          PL  51.40253
# 555    760778                            Radom          PL  51.40253
# 552    756135                           Warsaw          PL  52.22977
# 554    756135                            Varsa          PL  52.22977
# 553    756135                         Barsobia          PL  52.22977
# 463    734077                        Ftohomana          GR  40.64361
# 464    734077                        Ftohomána          GR  40.64361
# 462    734077                     Thessaloníki          GR  40.64361
# 29     728193                          Plovdiv          BG  42.15000
# 30     728193                        Eumolpias          BG  42.15000
# 31     728193                           Filiba          BG  42.15000
# 27     727011                              SOF          BG  42.69751
# 28     727011                           Safija          BG  42.69751
# 26     727011                            Sofia          BG  42.69751
# 24     726050                            Barna          BG  43.21667
# 23     726050                            Varna          BG  43.21667
# 25     726050                          Odessos          BG  43.21667
# 660    724443                           Košice          SK  48.71395
# 661    724443                         Cassovia          SK  48.71395
# 662    724443                              KSC          SK  48.71395
# 468    721472                         Debrecen          HU  47.53167
# 470    721472                         Debrecen          HU  47.53167
# 469    721472                              DEB          HU  47.53167
# 634    683844                          Brashov          RO  45.64861
# 633    683844                           Braşov          RO  45.64861
# 635    683844                           Brasov          RO  45.64861
# 632    683506                        Boekarest          RO  44.43225
# 631    683506                              BUH          RO  44.43225
# 630    683506                        Bucharest          RO  44.43225
# 629    681290                     Castrum Clus          RO  46.76667
#
#      longitude population
# 174    9.98400     315514
# 173    9.98400     315514
# 172    9.98400     315514
# 292   -3.73140     220085
# 291   -3.73140     220085
# 10    16.38233     201882
# 9     16.38233     201882
# 567   23.16433     291855
# 569   23.16433     291855
# 568   23.16433     291855
# 564   20.62752     208598
# 565   20.62752     208598
# 566   20.62752     208598
# 563   22.56667     360044
# 562   22.56667     360044
# 561   22.56667     360044
# 558   21.03487     217683
# 560   21.03487     217683
# 559   21.03487     217683
# 557   21.14714     226794
# 556   21.14714     226794
# 555   21.14714     226794
# 552   21.01178    1702139
# 554   21.01178    1702139
# 553   21.01178    1702139
# 463   22.93086     317778
# 464   22.93086     317778
# 462   22.93086     317778
# 29    24.75000     346893
# 30    24.75000     346893
# 31    24.75000     346893
# 27    23.32415    1152556
# 28    23.32415    1152556
# 26    23.32415    1152556
# 24    27.91667     312770
# 23    27.91667     312770
# 25    27.91667     312770
# 660   21.25808     225044
# 661   21.25808     225044
# 662   21.25808     225044
# 468   21.62444     202402
# 470   21.62444     202402
# 469   21.62444     202402
# 634   25.60613     253200
# 633   25.60613     253200
# 635   25.60613     253200
# 632   26.10626    1877155
# 631   26.10626    1877155
# 630   26.10626    1877155
# 629   23.60000     286598

# %%
AIRPORT_CITIES = [
    # Germany
    "Berlin", "München", "Frankfurt", "Hamburg", "Köln", "Düsseldorf", "Stuttgart", "Hannover", "Nürnberg", "Leipzig", "Dresden", "Bremen",
    # France
    "Paris", "Lyon", "Marseille", "Nice", "Toulouse", "Bordeaux", "Lille", "Strasbourg",
    # UK & Ireland
    "London", "Manchester", "Birmingham", "Edinburgh", "Glasgow", "Dublin",
    # Italy
    "Roma", "Milano", "Venezia", "Napoli", "Firenze", "Bologna", "Torino",
    # Spain & Portugal
    "Madrid", "Barcelona", "Sevilla", "Valencia", "Malaga", "Lisboa", "Porto",
    # Benelux
    "Amsterdam", "Rotterdam", "Den Haag", "Utrecht", "Bruxelles", "Brussels", "Antwerpen", "Luxembourg",
    # Central/East Europe
    "Wien", "Zürich", "Genève", "Basel", "Bern", "Praha", "Warszawa", "Krakow", "Budapest", "Bratislava", "Ljubljana", "Zagreb", "Bucuresti", "Sofia",
    # Nordics
    "København", "Stockholm", "Oslo", "Helsinki", "Malmö", "Göteborg"
]


MAIN_STATION_PATTERNS = [
    r"Hbf", r"Hauptbahnhof",                   # German/Austrian
    r"Centraal", r"Centrale", r"Central",      # Dutch/Italian/English/Nordic
    r"Termini", r"Tiburtina",                  # Roma
    r"Santa Maria Novella", r"S\.M\.N\.",      # Firenze
    r"Porta Nuova",                            # Torino
    r"Gare de Lyon", r"Gare du Nord", r"Gare de l'Est", r"Montparnasse", r"Saint-Lazare", # Paris
    r"Part-Dieu", r"Perrache",                 # Lyon
    r"St-Charles",                             # Marseille
    r"Ville",                                  # Nice Ville, Luxembourg Ville
    r"St Pancras", r"Euston", r"King's Cross", r"Paddington", r"Victoria", r"Waterloo", # London
    r"Piccadilly", r"Waverley", r"Connolly", r"Heuston", # UK/Ireland Regional
    r"Sants", r"Atocha", r"Chamartin", r"Santa Justa", r"Joaquin Sorolla", # Spain
    r"Campanha", r"Oriente", r"Santa Apolonia", # Portugal
    r"hl\.n\.", r"Glowny", r"Centralna",       # CZ/PL
    r"Keleti", r"Nyugati", r"Deli",            # Budapest
    r"Midi", r"Zuid", r"Noord", r"Brussels-South", # Brussels
    r"HB",                                     # Zurich/Swiss
]

def filter_major_hubs(df):
    """
    Filters a DataFrame of stations to return only Main Hubs in Airport Cities.
    Assumes df has columns: 'Station_Name', 'EVA_ID'
    """
    filtered_rows = []
    
    # Pre-compile regex for performance
    # Matches if any main station pattern exists in the string
    hub_regex = re.compile("|".join(MAIN_STATION_PATTERNS), re.IGNORECASE)
    
    print(f"Filtering {len(df)} stations...")

    for index, row in df.iterrows():
        raw_name = str(row.get('Station_Name', ''))
        eva_id = str(row.get('EVA_ID', ''))
        
        # 1. Normalize Name (remove brackets like '(Main)' or '(tief)')
        clean_name = raw_name.replace("(", " ").replace(")", " ").strip()
        
        # 2. Identify City
        found_city = None
        CITY_DB = set(AIRPORT_CITIES).union(set(CITIES_200K))
        for city in CITY_DB:
            # Logic: The city name must appear at the START of the station name
            # OR be a distinct word (e.g., "Flughafen Wien" -> matches Wien)
            # using regex boundary \b ensures we don't match "Bermuda" for "Bern"
            if re.search(rf"\b{city}\b", clean_name, re.IGNORECASE):
                found_city = city
                break
        
        if not found_city:
            continue
            
        # 3. Check for "Main Station" status
        is_hub = False
        
        # Check A: Explicit Keyword Match (e.g. "Hbf", "Termini")
        if hub_regex.search(clean_name):
            is_hub = True
            
        # Check B: The name IS the city name exactly (e.g. "München", "Nice", "Bratislava")
        # Some API data lists the main station just as the city name.
        if clean_name.lower() == found_city.lower():
            is_hub = True
            
        # Check C: Special handling for specific complex names
        # e.g., "Frankfurt(Main)Flughafen" -> We might want to EXCLUDE airports if we only want rail hubs,
        # OR include them if you want airport rail links.
        # Here we EXCLUDE actual airport stations to focus on CITY CENTRAL stations.
        if "Flughafen" in clean_name or "Airport" in clean_name:
            is_hub = False

        if is_hub:
            # Append normalized data
            row_data = row.to_dict()
            row_data['Assigned_City'] = found_city
            filtered_rows.append(row_data)

    # Create new DataFrame
    result_df = pd.DataFrame(filtered_rows)
    
    # Deduplicate: If multiple stations match for one city, keep them all 
    # (e.g. Paris has Nord and Est), but remove exact duplicates of EVA_ID.
    if not result_df.empty:
        result_df.drop_duplicates(subset=['EVA_ID'], inplace=True)
        result_df.sort_values(by=['Assigned_City', 'Station_Name'], inplace=True)
        
    return result_df

# %%
train_stations_df = filter_major_hubs(df)
train_stations_df.reset_index(drop=True, inplace=True)
train_stations_df
# Out:
# Filtering 28635 stations...
#       EVA_ID                             Station_Name  DS100      Country  \
# 0    8400058                       Amsterdam Centraal   XNAC  Netherlands
# 1    8498058              Amsterdam Centraal Eurostar  PNACE  Netherlands
# 2    8400048                    Amsterdam Noord Metro  PNANM  Netherlands
# 3    8400061                           Amsterdam Zuid   XNAZ  Netherlands
# 4    8800007                       Antwerpen Centraal   XBAC      Belgium
# ..       ...                                      ...    ...          ...
# 106  8170077  Hauptbahnhof (Wiedner Gürtel), Wien (A)  PAAAR      Austria
# 107  8103000                                 Wien Hbf  XAWIE      Austria
# 108  8100004            Wien Hbf (Autoreisezuganlage)  XAWIO      Austria
# 109  8101590                Wien Hbf (Bahnsteige 1-2)  OASRP      Austria
# 110  8174050           Wien Hbf (Busbahnhof Vorplatz)   OAWH      Austria
#
#     UIC_Code Assigned_City
# 0         84     Amsterdam
# 1         84     Amsterdam
# 2         84     Amsterdam
# 3         84     Amsterdam
# 4         88     Antwerpen
# ..       ...           ...
# 106       81          Wien
# 107       81          Wien
# 108       81          Wien
# 109       81          Wien
# 110       81          Wien
#
# [111 rows x 6 columns]

# %%
train_stations_df["Station_Name"]
# Out:
# 0                           Amsterdam Centraal
# 1                  Amsterdam Centraal Eurostar
# 2                        Amsterdam Noord Metro
# 3                               Amsterdam Zuid
# 4                           Antwerpen Centraal
#                         ...
# 106    Hauptbahnhof (Wiedner Gürtel), Wien (A)
# 107                                   Wien Hbf
# 108              Wien Hbf (Autoreisezuganlage)
# 109                  Wien Hbf (Bahnsteige 1-2)
# 110             Wien Hbf (Busbahnhof Vorplatz)
# Name: Station_Name, Length: 111, dtype: object

# %% [markdown]
# # Parsing Timetable for given stations

# %%
warsaw_eva:str = df.loc[df["Station_Name"] == "Warszawa Centralna"]["EVA_ID"]
warsaw_eva
# Out:
# 26877    5100065
# Name: EVA_ID, dtype: object

# %%
# retrieve for single week in 
def fetch_hourly_plan(eva_no, date_str, hour_str):
    """
    Fetches the planned timetable for a specific station, date (YYMMDD), and hour (HH).
    """
    url = f"{BASE_URL}/plan/{eva_no}/{date_str}/{hour_str}"
    try:
        response = requests.get(url, headers=header2)
        if response.status_code == 200:
            return response.text
        elif response.status_code == 404:
            return None 
        elif response.status_code == 401:
            print("[!] Authentication Failed. Check API Keys.")
            return None
        else:
            print(f"  [!] Error {response.status_code} for {hour_str}:00")
            return None
    except Exception as e:
        print(f"  [!] Request Error: {e}")
        return None

# %%
today = datetime.now()
schedule_date = today

for h in range(7):
    fetch_hourly_plan(warsaw_eva.values[0], schedule_date.strftime("%y%m%d"), "12")
# Out:
# '<?xml version=\'1.0\' encoding=\'UTF-8\'?><timetable station=\'Warszawa Centralna\'><s id="-1534404592360704587-2512231249-2"><tl f="F" t="p" o="51" c="EC" n="44"/><ar pt="2512231255" pp="" fb="EC 44" hi="1" ppth="Warszawa Wschodnia"/><dp pt="2512231300" pp="" fb="EC 44" ppth="Warszawa Zachodnia|Kutno|Konin|Poznan Glowny|Zbaszynek|Swiebodzin|Rzepin|Frankfurt(Oder)|Berlin Ostbahnhof|Berlin Hbf"/></s></timetable>'
